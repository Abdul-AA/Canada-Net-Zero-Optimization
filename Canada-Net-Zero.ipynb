# %% [markdown]
# ## Base Model: Hierarchical Multiobjective MIP

# %%
from gurobipy import Model, GRB

# Time periods
T = [2025, 2030, 2035]

# Energy sources
G = ['Wind', 'Solar', 'Oil', 'Nuclear', 'Hydro', 'Natural Gas', 'Coal', 'Geothermal']

# Emission factors for each energy source (MTCO2e/GWh) 
E_factor_data = {
    'Wind': [0.000015, 0.000015, 0.000015],
    'Solar': [0.0000445, 0.0000445, 0.0000445],
    'Oil': [0.00049, 0.00049, 0.00049],
    'Nuclear': [0.000012, 0.000012, 0.000012],
    'Hydro': [0.000024, 0.000024, 0.000024],
    'Natural Gas': [0.00049, 0.00049, 0.00049],
    'Coal': [0.00082, 0.00082, 0.00082],
    'Geothermal': [0.000038, 0.000038, 0.000038]
}

# Electricity demand for each time period (GWh) 
D_data = {2025: 611806.94, 2030: 694406.68, 2035: 787841.11} 

# Emission reduction  for each time period (#MTCO2e) 
Goals = {2025: 35.19, 2030: 28.89, 2035: 0}  


# Fixed generation capacity for each time period (GWh)  
Fixed_GEN_data = {
    'Wind': [64389.48],
    'Solar': [12184.92],
    'Oil': [1379.91],
    'Nuclear': [78631.37],
    'Hydro': [402575.9],
    'Natural Gas': [106529.07],
    'Coal': [8184.54],
    'Geothermal': [8281.2]
}


# Cost data for each energy source (CAD per GWh) 
Cost_data = {
    'Wind': [80830, 80830, 80830],
    'Solar': [205500, 205500, 205500],
    'Oil': [61650, 61650, 61650],
    'Nuclear': [89050, 89050, 89050],
    'Hydro': [30140, 30140, 30140],
    'Natural Gas': [97270, 97270, 97270],
    'Coal': [83570, 83570, 83570],
    'Geothermal': [82200, 82200, 82200]
}

# Capacity increase costs for each power plant type (CAD)
Increase_Cost = {
    'Nuclear': [9.59e9, 9.59e9, 9.59e9],
    'Solar': [12.878e9, 12.878e9, 12.878e9],
    'Wind': [4.11e9, 4.11e9, 4.11e9]
}

# Capacity increase amounts for each power plant type (GWh)
Capacity_Added = {
    'Nuclear': [48180, 48180, 48180],
    'Solar': [139809.6, 139809.6, 139809.6],
    'Wind': [43800, 43800, 43800]
}

# Create the model
m = Model("ImprovedCanadaEnergyModel")

# Decision Variables
# Generation for each energy source and time period
Gen = m.addVars(G, T, vtype=GRB.CONTINUOUS, name="Generation")

# Emissions for each energy source and time period
Emissions = m.addVars(G, T, vtype=GRB.CONTINUOUS, name="Emissions")

# Emission deviations for each time period
Deviation = m.addVars(T, vtype=GRB.CONTINUOUS, name="Deviation")

# Decision variables for capacity increase (only for Wind, Solar, Nuclear)
Capacity_Increase = m.addVars(['Wind', 'Solar', 'Nuclear'], T, vtype=GRB.CONTINUOUS, name="Capacity_Increase")

# Binary variables for capacity increase decision
Capacity_Increase_Decision = m.addVars(['Wind', 'Solar', 'Nuclear'],T,vtype=GRB.BINARY, name="CapacityIncreaseDecision")
Capacity_Increase_Decision_2 = m.addVars(['Wind', 'Solar', 'Nuclear'],T, vtype=GRB.BINARY, name="CapacityIncreaseDecision2")

# Objective Functions
# Objective 1: Minimize emissions deviation
m.setObjectiveN(sum(Deviation[t] for t in T), index=0, priority=1, name="Minimize_Emissions")

# Objective 2: Minimize cost 
Total_Cost = (
    sum(Cost_data[g][T.index(t)] * Gen[g, t] for g in G for t in T) +
    sum(Increase_Cost[g][T.index(t)] * Capacity_Increase_Decision[g, t] +Increase_Cost[g][T.index(t)] * Capacity_Increase_Decision_2[g, t] for g in ['Wind', 'Solar', 'Nuclear'] for t in T)  # Fixed opening cost
)
m.setObjectiveN(Total_Cost, index=1, priority=0, name="Minimize_Cost")

# Constraints
# Emission goals
m.addConstrs((sum(Emissions[g, t] for g in G) <= Goals[t] + Deviation[t] for t in T), "EmissionGoals")

# Emission calculations
m.addConstrs((Emissions[g, t] == E_factor_data[g][T.index(t)] * Gen[g, t] for g in G for t in T), "EmissionCalculation")

# Demand satisfaction
for t in T:
    m.addConstr(sum(Gen[g, t] for g in G) >= D_data[t], "DemandSatisfaction_" + str(t))

#fixed capacity limits for all sources in 2025
for g in G:
    m.addConstr(Gen[g, 2025] <= Fixed_GEN_data[g][T.index(2025)], f"FixedCapacityLimit_{g}_2025")

# Adjusted capacity limits for 2030
for g in G:
    if g in ['Wind', 'Solar', 'Nuclear']:
        # For Wind, Solar, and Nuclear, consider added capacity in 2030
        m.addConstr(Gen[g, 2030] <= Fixed_GEN_data[g][0] + Capacity_Increase[g, 2030], f"AdjustedCapacityLimit_{g}_2030")
    else:
        # For other sources, use fixed capacity limits in 2030
        m.addConstr(Gen[g, 2030] <= Fixed_GEN_data[g][0], f"FixedCapacityLimit_{g}_2030")

# Adjusted capacity limits for 2035, considering the capacity from 2030 and additional increase in 2035
for g in G:
    if g in ['Wind', 'Solar', 'Nuclear']:
        # For Wind, Solar, and Nuclear, consider the total capacity (2030 increase + 2035 increase)
        total_capacity_2035 = Fixed_GEN_data[g][0] + Capacity_Increase[g, 2030] + Capacity_Increase[g, 2035]
        m.addConstr(Gen[g, 2035] <= total_capacity_2035, f"TotalAdjustedCapacityLimit_{g}_2035")
    else:
        # For other sources, use fixed capacity limits in 2035
        m.addConstr(Gen[g, 2035] <= Fixed_GEN_data[g][0], f"FixedCapacityLimit_{g}_2035")


# Capacity increase constraints
for g in ['Wind', 'Solar', 'Nuclear']:
    for t in T[1:]:
                m.addConstr(Capacity_Increase[g, t] <= Capacity_Increase_Decision[g, t] * Capacity_Added[g][T.index(t)] +
                Capacity_Increase_Decision_2[g, t] * Capacity_Added[g][T.index(t)] , f"CapacityIncreaseLink_{g}_{t}")



#constraint to make sure powerplants are only added if existing capacity is not enough
utilization_threshold = 1  # Define a threshold for capacity utilization
M = 1e15  

for g in ['Wind', 'Solar', 'Nuclear']:
    for t in T[1:]:  
        existing_capacity_expr = Fixed_GEN_data[g][0] + sum(Capacity_Increase[g, year] for year in T if year < t)

        # Binary variable indicating if capacity increase is needed
        y_gt = m.addVar(vtype=GRB.BINARY, name=f"y_{g}_{t}")
        m.addConstr(Capacity_Increase_Decision[g, t] + M*y_gt >=1)
        m.addConstr(Gen[g, t] - (utilization_threshold * existing_capacity_expr) - M * (1-y_gt) <= 0, name=f"ThresholdCheck_{g}_{t}")
        
        # Binary variable indicating if second capacity increase is needed
        y_gt2 = m.addVar(vtype=GRB.BINARY, name=f"y_{g}_{t}_2")
        m.addConstr(Capacity_Increase_Decision_2[g, t] + M * y_gt2 >= 1)
        m.addConstr(Gen[g, t] - (utilization_threshold * (existing_capacity_expr + Capacity_Added[g][T.index(t)])) - M * (1 - y_gt2) <= 0, name=f"ThresholdCheck_{g}_{t}_2")
#constraint capacity incease 2025 for renewables is 0
m.addConstr(Capacity_Increase['Wind', 2025] == 0)
m.addConstr(Capacity_Increase['Solar', 2025] == 0)
m.addConstr(Capacity_Increase['Nuclear', 2025] == 0)


# Phase out non-renewables
m.addConstr(Gen['Coal', 2030] == 0, "Coal_PhaseOut_2035")
m.addConstr(Gen['Oil', 2035] == 0, "Oil_PhaseOut_2035")
m.addConstr(Gen['Coal', 2035] == 0, "Coal_PhaseOut_2035")




    
    
# Optimize the model
m.optimize()

# Output results
if m.status == GRB.OPTIMAL:
    for t in T:
        print(f"Year {t}:")

        # Initialize variables to store total costs and generations
        total_cost_year = 0
        total_emissions_year = 0
        total_generation_year = 0
        total_capacity_increase_cost_year = 0  # Total cost of adding capacity for the year
        total_generation_cost_year = 0  # Total cost of generating electricity for the year
        deviation_year = Deviation[t].x

        # Print generation, emissions, and cost for each energy source
        for g in G:
            generation = Gen[g, t].x
            emissions = Emissions[g, t].x
            cost = generation * Cost_data[g][T.index(t)]

            total_generation_year += generation
            total_emissions_year += emissions
            total_generation_cost_year += cost

            print(f"  Generation ({g}): {generation} GWh")
            print(f"  Emissions ({g}): {emissions} MTCO2e")
            print(f"  Generation Cost ({g}): {cost} CAD")

        # Check and print details for each power plant type opened
        for g in ['Wind', 'Solar', 'Nuclear']:
            # First power plant
            power_plant_opened = Capacity_Increase_Decision[g, t].x
            if power_plant_opened > 0.5:  # Power plant opened in year t
                added_capacity = Capacity_Added[g][T.index(t)]
                cost_of_increase = Increase_Cost[g][T.index(t)]
                total_capacity_increase_cost_year += cost_of_increase

                print(f"  Power Plant Type Opened in {t}: {g}")
                print(f"  Added Capacity for {g} in {t}: {added_capacity} GWh")
                print(f"  Cost of Capacity Increase for {g} in {t}: {cost_of_increase} CAD")
            else:
                print(f"  No {g} Power Plant Opened in {t}")

            # Second power plant
            power_plant_opened_2 = Capacity_Increase_Decision_2[g, t].x
            if power_plant_opened_2 > 0.5:  # Second power plant opened in year t
                added_capacity = Capacity_Added[g][T.index(t)]
                cost_of_increase = Increase_Cost[g][T.index(t)]
                total_capacity_increase_cost_year += cost_of_increase

                print(f"  Second Power Plant Type Opened in {t}: {g}")
                print(f"  Added Capacity for {g} in {t}: {added_capacity} GWh")
                print(f"  Cost of Capacity Increase for {g} in {t}: {cost_of_increase} CAD")
            else:
                print(f"  No Second {g} Power Plant Opened in {t}")

        # Calculate and print total available capacity for Wind, Solar, and Nuclear
        for g in ['Wind', 'Solar', 'Nuclear']:
            total_capacity = Fixed_GEN_data[g][0]
            for year in T:
                if year <= t:
                    added_capacity = Capacity_Increase_Decision[g, year].x * Capacity_Added[g][T.index(year)]
                    added_capacity += Capacity_Increase_Decision_2[g, year].x * Capacity_Added[g][T.index(year)]
                    total_capacity += added_capacity
            print(f"  Total Available Capacity for {g} in {t}: {total_capacity} GWh")

        # Print total costs and generations
        total_cost_year = total_generation_cost_year + total_capacity_increase_cost_year
        print(f"Total Generation Cost for Year {t}: {total_generation_cost_year} CAD")
        print(f"Total Capacity Increase Cost for Year {t}: {total_capacity_increase_cost_year} CAD")
        print(f"Total Cost for Year {t}: {total_cost_year} CAD")
        print(f"Total Generation for Year {t}: {total_generation_year} GWh")
        print(f"Total Emissions for Year {t}: {total_emissions_year} MTCO2e")
        print(f"Emission Deviation for Year {t}: {deviation_year}")
else:
    print("No optimal solution found.")
# Out:
# Gurobi Optimizer version 10.0.1 build v10.0.1rc0 (mac64[x86])
#
# CPU model: Intel(R) Core(TM) i5-5250U CPU @ 1.60GHz
# Thread count: 2 physical cores, 4 logical processors, using up to 4 threads
#
# Optimize a model with 90 rows, 90 columns and 222 nonzeros
# Model fingerprint: 0x79bf2654
# Variable types: 60 continuous, 30 integer (30 binary)
# Coefficient statistics:
#   Matrix range     [1e-05, 1e+15]
#   Objective range  [1e+00, 1e+10]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+15]
# Warning: Model contains large matrix coefficient range
# Warning: Model contains large objective coefficients
# Warning: Model contains large rhs
#          Consider reformulating model or setting NumericFocus parameter
#          to avoid numerical issues.
#
# ---------------------------------------------------------------------------
# Multi-objectives: starting optimization with 2 objectives ...
# ---------------------------------------------------------------------------
#
# Multi-objectives: applying initial presolve ...
# ---------------------------------------------------------------------------
#
# Presolve removed 48 rows and 30 columns
# Presolve time: 0.00s
# Presolved: 42 rows and 60 columns
# ---------------------------------------------------------------------------
# Multi-objectives: optimize objective 1 (Minimize_Emissions) ...
# ---------------------------------------------------------------------------
#
# Found heuristic solution: objective 150.6183069
# Presolve removed 40 rows and 53 columns
# Presolve time: 0.00s
# Presolved: 2 rows, 7 columns, 13 nonzeros
# Found heuristic solution: objective 74.2648242
# Variable types: 7 continuous, 0 integer (0 binary)
#
# Root relaxation: objective 1.349566e+01, 7 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0      13.4956649   13.49566  0.00%     -    0s
#
# Explored 1 nodes (7 simplex iterations) in 0.17 seconds (0.00 work units)
# Thread count was 4 (of 4 available processors)
#
# Solution count 2: 13.4957 150.618
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.349566488000e+01, best bound 1.349566488000e+01, gap 0.0000%
# ---------------------------------------------------------------------------
#
# Multi-objectives: optimize objective 2 (Minimize_Cost) ...
# ---------------------------------------------------------------------------
#
#
# Loaded user MIP start with objective 2.90761e+11
#
# Presolve removed 23 rows and 31 columns
# Presolve time: 0.00s
# Presolved: 20 rows, 29 columns, 80 nonzeros
# Found heuristic solution: objective 1.752937e+11
# Variable types: 16 continuous, 13 integer (12 binary)
#
# Root relaxation: objective 1.752650e+11, 13 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 1.7526e+11    0    1 1.7529e+11 1.7526e+11  0.02%     -    0s
#      0     0          -    0      1.7529e+11 1.7529e+11  0.00%     -    0s
#
# Explored 1 nodes (14 simplex iterations) in 0.25 seconds (0.00 work units)
# Thread count was 4 (of 4 available processors)
#
# Solution count 2: 1.75294e+11 2.90761e+11
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.752936726712e+11, best bound 1.752863940879e+11, gap 0.0042%
#
# ---------------------------------------------------------------------------
# Multi-objectives: solved in 0.27 seconds (0.00 work units), solution count 3
#
# Year 2025:
#   Generation (Wind): 64389.48 GWh
#   Emissions (Wind): 0.9658422000000001 MTCO2e
#   Generation Cost (Wind): 5204601668.400001 CAD
#   Generation (Solar): 11402.425080834817 GWh
#   Emissions (Solar): 0.5074079160971493 MTCO2e
#   Generation Cost (Solar): 2343198354.111555 CAD
#   Generation (Oil): 1379.91 GWh
#   Emissions (Oil): 0.6761559 MTCO2e
#   Generation Cost (Oil): 85071451.5 CAD
#   Generation (Nuclear): 78631.37 GWh
#   Emissions (Nuclear): 0.94357644 MTCO2e
#   Generation Cost (Nuclear): 7002123498.5 CAD
#   Generation (Hydro): 402575.9 GWh
#   Emissions (Hydro): 9.661821600000001 MTCO2e
#   Generation Cost (Hydro): 12133637626.0 CAD
#   Generation (Natural Gas): 45146.6549191651 GWh
#   Emissions (Natural Gas): 22.121860910390897 MTCO2e
#   Generation Cost (Natural Gas): 4391415123.987189 CAD
#   Generation (Coal): 0.0 GWh
#   Emissions (Coal): 0.0 MTCO2e
#   Generation Cost (Coal): 0.0 CAD
#   Generation (Geothermal): 8281.2 GWh
#   Emissions (Geothermal): 0.31468560000000007 MTCO2e
#   Generation Cost (Geothermal): 680714640.0000001 CAD
#   No Wind Power Plant Opened in 2025
#   No Second Wind Power Plant Opened in 2025
#   No Solar Power Plant Opened in 2025
#   No Second Solar Power Plant Opened in 2025
#   No Nuclear Power Plant Opened in 2025
#   No Second Nuclear Power Plant Opened in 2025
#   Total Available Capacity for Wind in 2025: 64389.48 GWh
#   Total Available Capacity for Solar in 2025: 12184.92 GWh
#   Total Available Capacity for Nuclear in 2025: 78631.37 GWh
# Total Generation Cost for Year 2025: 31840762362.498745 CAD
# Total Capacity Increase Cost for Year 2025: 0 CAD
# Total Cost for Year 2025: 31840762362.498745 CAD
# Total Generation for Year 2025: 611806.9399999998 GWh
# Total Emissions for Year 2025: 35.19135056648805 MTCO2e
# Emission Deviation for Year 2025: 0.0013505664880479884
# Year 2030:
#   Generation (Wind): 151989.48000000004 GWh
#   Emissions (Wind): 2.2798422000000005 MTCO2e
#   Generation Cost (Wind): 12285309668.400003 CAD
#   Generation (Solar): 0.0 GWh
#   Emissions (Solar): 0.0 MTCO2e
#   Generation Cost (Solar): 0.0 CAD
#   Generation (Oil): 1379.91 GWh
#   Emissions (Oil): 0.6761559 MTCO2e
#   Generation Cost (Oil): 85071451.5 CAD
#   Generation (Nuclear): 130180.1899999999 GWh
#   Emissions (Nuclear): 1.5621622799999988 MTCO2e
#   Generation Cost (Nuclear): 11592545919.49999 CAD
#   Generation (Hydro): 402575.9 GWh
#   Emissions (Hydro): 9.661821600000001 MTCO2e
#   Generation Cost (Hydro): 12133637626.0 CAD
#   Generation (Natural Gas): 0.0 GWh
#   Emissions (Natural Gas): 0.0 MTCO2e
#   Generation Cost (Natural Gas): 0.0 CAD
#   Generation (Coal): 0.0 GWh
#   Emissions (Coal): 0.0 MTCO2e
#   Generation Cost (Coal): 0.0 CAD
#   Generation (Geothermal): 8281.2 GWh
#   Emissions (Geothermal): 0.31468560000000007 MTCO2e
#   Generation Cost (Geothermal): 680714640.0000001 CAD
#   Power Plant Type Opened in 2030: Wind
#   Added Capacity for Wind in 2030: 43800 GWh
#   Cost of Capacity Increase for Wind in 2030: 4110000000.0 CAD
#   Second Power Plant Type Opened in 2030: Wind
#   Added Capacity for Wind in 2030: 43800 GWh
#   Cost of Capacity Increase for Wind in 2030: 4110000000.0 CAD
#   No Solar Power Plant Opened in 2030
#   No Second Solar Power Plant Opened in 2030
#   Power Plant Type Opened in 2030: Nuclear
#   Added Capacity for Nuclear in 2030: 48180 GWh
#   Cost of Capacity Increase for Nuclear in 2030: 9590000000.0 CAD
#   Second Power Plant Type Opened in 2030: Nuclear
#   Added Capacity for Nuclear in 2030: 48180 GWh
#   Cost of Capacity Increase for Nuclear in 2030: 9590000000.0 CAD
#   Total Available Capacity for Wind in 2030: 151989.48 GWh
#   Total Available Capacity for Solar in 2030: 12184.92 GWh
#   Total Available Capacity for Nuclear in 2030: 174991.37 GWh
# Total Generation Cost for Year 2030: 36777279305.399994 CAD
# Total Capacity Increase Cost for Year 2030: 27400000000.0 CAD
# Total Cost for Year 2030: 64177279305.399994 CAD
# Total Generation for Year 2030: 694406.6799999999 GWh
# Total Emissions for Year 2030: 14.494667580000002 MTCO2e
# Emission Deviation for Year 2030: 0.0
# Year 2035:
#   Generation (Wind): 239589.48000000004 GWh
#   Emissions (Wind): 3.5938422000000005 MTCO2e
#   Generation Cost (Wind): 19366017668.4 CAD
#   Generation (Solar): 0.0 GWh
#   Emissions (Solar): 0.0 MTCO2e
#   Generation Cost (Solar): 0.0 CAD
#   Generation (Oil): 0.0 GWh
#   Emissions (Oil): 0.0 MTCO2e
#   Generation Cost (Oil): 0.0 CAD
#   Generation (Nuclear): 271351.37 GWh
#   Emissions (Nuclear): 3.25621644 MTCO2e
#   Generation Cost (Nuclear): 24163839498.5 CAD
#   Generation (Hydro): 276900.2599999999 GWh
#   Emissions (Hydro): 6.6456062399999976 MTCO2e
#   Generation Cost (Hydro): 8345773836.399997 CAD
#   Generation (Natural Gas): 0.0 GWh
#   Emissions (Natural Gas): 0.0 MTCO2e
#   Generation Cost (Natural Gas): 0.0 CAD
#   Generation (Coal): 0.0 GWh
#   Emissions (Coal): 0.0 MTCO2e
#   Generation Cost (Coal): 0.0 CAD
#   Generation (Geothermal): 0.0 GWh
#   Emissions (Geothermal): 0.0 MTCO2e
#   Generation Cost (Geothermal): 0.0 CAD
#   Power Plant Type Opened in 2035: Wind
#   Added Capacity for Wind in 2035: 43800 GWh
#   Cost of Capacity Increase for Wind in 2035: 4110000000.0 CAD
#   Second Power Plant Type Opened in 2035: Wind
#   Added Capacity for Wind in 2035: 43800 GWh
#   Cost of Capacity Increase for Wind in 2035: 4110000000.0 CAD
#   No Solar Power Plant Opened in 2035
#   No Second Solar Power Plant Opened in 2035
#   Power Plant Type Opened in 2035: Nuclear
#   Added Capacity for Nuclear in 2035: 48180 GWh
#   Cost of Capacity Increase for Nuclear in 2035: 9590000000.0 CAD
#   Second Power Plant Type Opened in 2035: Nuclear
#   Added Capacity for Nuclear in 2035: 48180 GWh
#   Cost of Capacity Increase for Nuclear in 2035: 9590000000.0 CAD
#   Total Available Capacity for Wind in 2035: 239589.48 GWh
#   Total Available Capacity for Solar in 2035: 12184.92 GWh
#   Total Available Capacity for Nuclear in 2035: 271351.37 GWh
# Total Generation Cost for Year 2035: 51875631003.299995 CAD
# Total Capacity Increase Cost for Year 2035: 27400000000.0 CAD
# Total Cost for Year 2035: 79275631003.29999 CAD
# Total Generation for Year 2035: 787841.1099999999 GWh
# Total Emissions for Year 2035: 13.495664879999998 MTCO2e
# Emission Deviation for Year 2035: 13.49566487999995

# %% [markdown]
# ## Printing all the Decision Variables

# %%
for v in m.getVars():
    print(v.varName, v.x)
# Out:
# Generation[Wind,2025] 64389.48
# Generation[Wind,2030] 151989.48000000004
# Generation[Wind,2035] 239589.48000000004
# Generation[Solar,2025] 11402.425080834817
# Generation[Solar,2030] 0.0
# Generation[Solar,2035] 0.0
# Generation[Oil,2025] 1379.91
# Generation[Oil,2030] 1379.91
# Generation[Oil,2035] 0.0
# Generation[Nuclear,2025] 78631.37
# Generation[Nuclear,2030] 130180.1899999999
# Generation[Nuclear,2035] 271351.37
# Generation[Hydro,2025] 402575.9
# Generation[Hydro,2030] 402575.9
# Generation[Hydro,2035] 276900.2599999999
# Generation[Natural Gas,2025] 45146.6549191651
# Generation[Natural Gas,2030] 0.0
# Generation[Natural Gas,2035] 0.0
# Generation[Coal,2025] 0.0
# Generation[Coal,2030] 0.0
# Generation[Coal,2035] 0.0
# Generation[Geothermal,2025] 8281.2
# Generation[Geothermal,2030] 8281.2
# Generation[Geothermal,2035] 0.0
# Emissions[Wind,2025] 0.9658422000000001
# Emissions[Wind,2030] 2.2798422000000005
# Emissions[Wind,2035] 3.5938422000000005
# Emissions[Solar,2025] 0.5074079160971493
# Emissions[Solar,2030] 0.0
# Emissions[Solar,2035] 0.0
# Emissions[Oil,2025] 0.6761559
# Emissions[Oil,2030] 0.6761559
# Emissions[Oil,2035] 0.0
# Emissions[Nuclear,2025] 0.94357644
# Emissions[Nuclear,2030] 1.5621622799999988
# Emissions[Nuclear,2035] 3.25621644
# Emissions[Hydro,2025] 9.661821600000001
# Emissions[Hydro,2030] 9.661821600000001
# Emissions[Hydro,2035] 6.6456062399999976
# Emissions[Natural Gas,2025] 22.121860910390897
# Emissions[Natural Gas,2030] 0.0
# Emissions[Natural Gas,2035] 0.0
# Emissions[Coal,2025] 0.0
# Emissions[Coal,2030] 0.0
# Emissions[Coal,2035] 0.0
# Emissions[Geothermal,2025] 0.31468560000000007
# Emissions[Geothermal,2030] 0.31468560000000007
# Emissions[Geothermal,2035] 0.0
# Deviation[2025] 0.0013505664880479884
# Deviation[2030] 0.0
# Deviation[2035] 13.49566487999995
# Capacity_Increase[Wind,2025] 0.0
# Capacity_Increase[Wind,2030] 87600.0
# Capacity_Increase[Wind,2035] 87600.0
# Capacity_Increase[Solar,2025] 0.0
# Capacity_Increase[Solar,2030] 0.0
# Capacity_Increase[Solar,2035] 0.0
# Capacity_Increase[Nuclear,2025] 0.0
# Capacity_Increase[Nuclear,2030] 96360.0
# Capacity_Increase[Nuclear,2035] 96360.0
# CapacityIncreaseDecision[Wind,2025] 0.0
# CapacityIncreaseDecision[Wind,2030] 1.0
# CapacityIncreaseDecision[Wind,2035] 1.0
# CapacityIncreaseDecision[Solar,2025] 0.0
# CapacityIncreaseDecision[Solar,2030] 0.0
# CapacityIncreaseDecision[Solar,2035] 0.0
# CapacityIncreaseDecision[Nuclear,2025] 0.0
# CapacityIncreaseDecision[Nuclear,2030] 1.0
# CapacityIncreaseDecision[Nuclear,2035] 1.0
# CapacityIncreaseDecision2[Wind,2025] 0.0
# CapacityIncreaseDecision2[Wind,2030] 1.0
# CapacityIncreaseDecision2[Wind,2035] 1.0
# CapacityIncreaseDecision2[Solar,2025] 0.0
# CapacityIncreaseDecision2[Solar,2030] 0.0
# CapacityIncreaseDecision2[Solar,2035] 0.0
# CapacityIncreaseDecision2[Nuclear,2025] 0.0
# CapacityIncreaseDecision2[Nuclear,2030] 1.0
# CapacityIncreaseDecision2[Nuclear,2035] 1.0
# y_Wind_2030 0.0
# y_Wind_2030_2 0.0
# y_Wind_2035 0.0
# y_Wind_2035_2 0.0
# y_Solar_2030 1.0
# y_Solar_2030_2 1.0
# y_Solar_2035 1.0
# y_Solar_2035_2 1.0
# y_Nuclear_2030 0.0
# y_Nuclear_2030_2 0.0
# y_Nuclear_2035 0.0
# y_Nuclear_2035_2 0.0

# %% [markdown]
# ## Sensitivity Analysis
#
# #### Which constraints are binding?

# %%
import pandas as pd

# Prepare lists to hold constraint information
constraint_names = []
constraint_sense = []
constraint_slack = []
constraint_rhs = []

for constr in m.getConstrs():
    constraint_names.append(constr.ConstrName)
    constraint_sense.append(constr.Sense)
    constraint_slack.append(constr.Slack)
    constraint_rhs.append(constr.RHS)

constraints_df = pd.DataFrame({
    'Sense': constraint_sense,
    'Slack': constraint_slack,
    'RHS': constraint_rhs
},index=constraint_names)

# Display the DataFrame showing all the rows
pd.set_option('display.max_rows', None)
constraints_df
# Out:
#                                         Sense         Slack           RHS
# EmissionGoals[2025]                         <  0.000000e+00  3.519000e+01
# EmissionGoals[2030]                         <  1.439533e+01  2.889000e+01
# EmissionGoals[2035]                         < -4.796163e-14  0.000000e+00
# EmissionCalculation[Wind,2025]              =  0.000000e+00  0.000000e+00
# EmissionCalculation[Wind,2030]              =  0.000000e+00  0.000000e+00
# EmissionCalculation[Wind,2035]              =  0.000000e+00  0.000000e+00
# EmissionCalculation[Solar,2025]             =  0.000000e+00  0.000000e+00
# EmissionCalculation[Solar,2030]             =  0.000000e+00  0.000000e+00
# EmissionCalculation[Solar,2035]             =  0.000000e+00  0.000000e+00
# EmissionCalculation[Oil,2025]               =  0.000000e+00  0.000000e+00
# EmissionCalculation[Oil,2030]               =  0.000000e+00  0.000000e+00
# EmissionCalculation[Oil,2035]               =  0.000000e+00  0.000000e+00
# EmissionCalculation[Nuclear,2025]           =  0.000000e+00  0.000000e+00
# EmissionCalculation[Nuclear,2030]           =  0.000000e+00  0.000000e+00
# EmissionCalculation[Nuclear,2035]           =  0.000000e+00  0.000000e+00
# EmissionCalculation[Hydro,2025]             =  0.000000e+00  0.000000e+00
# EmissionCalculation[Hydro,2030]             =  0.000000e+00  0.000000e+00
# EmissionCalculation[Hydro,2035]             =  0.000000e+00  0.000000e+00
# EmissionCalculation[Natural Gas,2025]       =  0.000000e+00  0.000000e+00
# EmissionCalculation[Natural Gas,2030]       =  0.000000e+00  0.000000e+00
# EmissionCalculation[Natural Gas,2035]       =  0.000000e+00  0.000000e+00
# EmissionCalculation[Coal,2025]              =  0.000000e+00  0.000000e+00
# EmissionCalculation[Coal,2030]              =  0.000000e+00  0.000000e+00
# EmissionCalculation[Coal,2035]              =  0.000000e+00  0.000000e+00
# EmissionCalculation[Geothermal,2025]        =  0.000000e+00  0.000000e+00
# EmissionCalculation[Geothermal,2030]        =  0.000000e+00  0.000000e+00
# EmissionCalculation[Geothermal,2035]        =  0.000000e+00  0.000000e+00
# DemandSatisfaction_2025                     >  1.164153e-10  6.118069e+05
# DemandSatisfaction_2030                     >  1.164153e-10  6.944067e+05
# DemandSatisfaction_2035                     >  1.164153e-10  7.878411e+05
# FixedCapacityLimit_Wind_2025                <  0.000000e+00  6.438948e+04
# FixedCapacityLimit_Solar_2025               <  7.824949e+02  1.218492e+04
# FixedCapacityLimit_Oil_2025                 <  0.000000e+00  1.379910e+03
# FixedCapacityLimit_Nuclear_2025             <  0.000000e+00  7.863137e+04
# FixedCapacityLimit_Hydro_2025               <  0.000000e+00  4.025759e+05
# FixedCapacityLimit_Natural Gas_2025         <  6.138242e+04  1.065291e+05
# FixedCapacityLimit_Coal_2025                <  8.184540e+03  8.184540e+03
# FixedCapacityLimit_Geothermal_2025          <  0.000000e+00  8.281200e+03
# AdjustedCapacityLimit_Wind_2030             < -3.637979e-11  6.438948e+04
# AdjustedCapacityLimit_Solar_2030            <  1.218492e+04  1.218492e+04
# FixedCapacityLimit_Oil_2030                 <  0.000000e+00  1.379910e+03
# AdjustedCapacityLimit_Nuclear_2030          <  4.481118e+04  7.863137e+04
# FixedCapacityLimit_Hydro_2030               <  0.000000e+00  4.025759e+05
# FixedCapacityLimit_Natural Gas_2030         <  1.065291e+05  1.065291e+05
# FixedCapacityLimit_Coal_2030                <  8.184540e+03  8.184540e+03
# FixedCapacityLimit_Geothermal_2030          <  0.000000e+00  8.281200e+03
# TotalAdjustedCapacityLimit_Wind_2035        < -3.637979e-11  6.438948e+04
# TotalAdjustedCapacityLimit_Solar_2035       <  1.218492e+04  1.218492e+04
# FixedCapacityLimit_Oil_2035                 <  1.379910e+03  1.379910e+03
# TotalAdjustedCapacityLimit_Nuclear_2035     <  0.000000e+00  7.863137e+04
# FixedCapacityLimit_Hydro_2035               <  1.256756e+05  4.025759e+05
# FixedCapacityLimit_Natural Gas_2035         <  1.065291e+05  1.065291e+05
# FixedCapacityLimit_Coal_2035                <  8.184540e+03  8.184540e+03
# FixedCapacityLimit_Geothermal_2035          <  8.281200e+03  8.281200e+03
# CapacityIncreaseLink_Wind_2030              <  0.000000e+00  0.000000e+00
# CapacityIncreaseLink_Wind_2035              <  0.000000e+00  0.000000e+00
# CapacityIncreaseLink_Solar_2030             <  0.000000e+00  0.000000e+00
# CapacityIncreaseLink_Solar_2035             <  0.000000e+00  0.000000e+00
# CapacityIncreaseLink_Nuclear_2030           <  0.000000e+00  0.000000e+00
# CapacityIncreaseLink_Nuclear_2035           <  0.000000e+00  0.000000e+00
# R60                                         > -0.000000e+00  1.000000e+00
# ThresholdCheck_Wind_2030                    <  1.000000e+15  1.000000e+15
# R62                                         > -0.000000e+00  1.000000e+00
# ThresholdCheck_Wind_2030_2                  <  1.000000e+15  1.000000e+15
# R64                                         > -0.000000e+00  1.000000e+00
# ThresholdCheck_Wind_2035                    <  1.000000e+15  1.000000e+15
# R66                                         > -0.000000e+00  1.000000e+00
# ThresholdCheck_Wind_2035_2                  <  1.000000e+15  1.000000e+15
# R68                                         > -1.000000e+15  1.000000e+00
# ThresholdCheck_Solar_2030                   <  1.218488e+04  1.000000e+15
# R70                                         > -1.000000e+15  1.000000e+00
# ThresholdCheck_Solar_2030_2                 <  1.519945e+05  1.000000e+15
# R72                                         > -1.000000e+15  1.000000e+00
# ThresholdCheck_Solar_2035                   <  1.218488e+04  1.000000e+15
# R74                                         > -1.000000e+15  1.000000e+00
# ThresholdCheck_Solar_2035_2                 <  1.519945e+05  1.000000e+15
# R76                                         > -0.000000e+00  1.000000e+00
# ThresholdCheck_Nuclear_2030                 <  1.000000e+15  1.000000e+15
# R78                                         > -0.000000e+00  1.000000e+00
# ThresholdCheck_Nuclear_2030_2               <  1.000000e+15  1.000000e+15
# R80                                         > -0.000000e+00  1.000000e+00
# ThresholdCheck_Nuclear_2035                 <  1.000000e+15  1.000000e+15
# R82                                         > -0.000000e+00  1.000000e+00
# ThresholdCheck_Nuclear_2035_2               <  1.000000e+15  1.000000e+15
# R84                                         =  0.000000e+00  0.000000e+00
# R85                                         =  0.000000e+00  0.000000e+00
# R86                                         =  0.000000e+00  0.000000e+00
# Coal_PhaseOut_2035                          =  0.000000e+00  0.000000e+00
# Oil_PhaseOut_2035                           =  0.000000e+00  0.000000e+00
# Coal_PhaseOut_2035                          =  0.000000e+00  0.000000e+00

# %% [markdown]
# ## Demand Uncertainty
#
# #### How does increase in demand affect the model?
#
#
# - The model is very sensitive to increase in demand. The emission deviation in 2025 increases with even 1% increase in demand. Interestingly, increase in demand in 2025 reduces the emission deviation probably because the model needs to meet the demand by allocating more resources from renewable sources regardless of the cost

# %%
from gurobipy import Model, GRB

# Time periods
T = [2025, 2030, 2035]

# Energy sources
G = ['Wind', 'Solar', 'Oil', 'Nuclear', 'Hydro', 'Natural Gas', 'Coal', 'Geothermal']

# Emission factors for each energy source (MTCO2e/GWh) 
E_factor_data = {
    'Wind': [0.000015, 0.000015, 0.000015],
    'Solar': [0.0000445, 0.0000445, 0.0000445],
    'Oil': [0.00049, 0.00049, 0.00049],
    'Nuclear': [0.000012, 0.000012, 0.000012],
    'Hydro': [0.000024, 0.000024, 0.000024],
    'Natural Gas': [0.00049, 0.00049, 0.00049],
    'Coal': [0.00082, 0.00082, 0.00082],
    'Geothermal': [0.000038, 0.000038, 0.000038]
}
# Electricity demand for each time period (GWh) 
D_data = {2025: 611806.94, 2030: 694406.68, 2035: 787841.11} 

# Emission reduction  for each time period (#MTCO2e) 
Goals = {2025: 35.19, 2030: 28.89, 2035: 0}  


# Fixed generation capacity for each time period (GWh) 
Fixed_GEN_data = {
    'Wind': [64389.48],
    'Solar': [12184.92],
    'Oil': [1379.91],
    'Nuclear': [78631.37],
    'Hydro': [402575.9],
    'Natural Gas': [106529.07],
    'Coal': [8184.54],
    'Geothermal': [8281.2]
}


# Cost data for each energy source (CAD per GWh) 
Cost_data = {
    'Wind': [80830, 80830, 80830],
    'Solar': [205500, 205500, 205500],
    'Oil': [61650, 61650, 61650],
    'Nuclear': [89050, 89050, 89050],
    'Hydro': [30140, 30140, 30140],
    'Natural Gas': [97270, 97270, 97270],
    'Coal': [83570, 83570, 83570],
    'Geothermal': [82200, 82200, 82200]
}

# Capacity increase costs for each power plant type (CAD)
Increase_Cost = {
    'Nuclear': [9.59e9, 9.59e9, 9.59e9],
    'Solar': [12.878e9, 12.878e9, 12.878e9],
    'Wind': [4.11e9, 4.11e9, 4.11e9]
}

# Capacity increase amounts for each power plant type (GWh)
Capacity_Added = {
    'Nuclear': [48180, 48180, 48180],
    'Solar': [139809.6, 139809.6, 139809.6],
    'Wind': [43800, 43800, 43800]
}

# Create the model
m = Model("ImprovedCanadaEnergyModel")

# Decision Variables
# Generation for each energy source and time period
Gen = m.addVars(G, T, vtype=GRB.CONTINUOUS, name="Generation")

# Emissions for each energy source and time period
Emissions = m.addVars(G, T, vtype=GRB.CONTINUOUS, name="Emissions")

# Emission deviations for each time period
Deviation = m.addVars(T, vtype=GRB.CONTINUOUS, name="Deviation")

# Decision variables for capacity increase (only for Wind, Solar, Nuclear)
Capacity_Increase = m.addVars(['Wind', 'Solar', 'Nuclear'], [2030,2035], vtype=GRB.CONTINUOUS, name="Capacity_Increase")

# Binary variables for capacity increase decision
Capacity_Increase_Decision = m.addVars(['Wind', 'Solar', 'Nuclear'],T,vtype=GRB.BINARY, name="CapacityIncreaseDecision")
Capacity_Increase_Decision_2 = m.addVars(['Wind', 'Solar', 'Nuclear'],T, vtype=GRB.BINARY, name="CapacityIncreaseDecision2")

# Objective Functions
# Objective 1: Minimize emissions deviation
m.setObjectiveN(sum(Deviation[t] for t in T), index=0, priority=1, name="Minimize_Emissions")

# Objective 2: Minimize cost 
Total_Cost = (
    sum(Cost_data[g][T.index(t)] * Gen[g, t] for g in G for t in T) +
    sum(Increase_Cost[g][T.index(t)] * Capacity_Increase_Decision[g, t] +Increase_Cost[g][T.index(t)] * Capacity_Increase_Decision_2[g, t] for g in ['Wind', 'Solar', 'Nuclear'] for t in T)  # Fixed opening cost
)
m.setObjectiveN(Total_Cost, index=1, priority=0, name="Minimize_Cost")

# Constraints
# Emission goals
m.addConstrs((sum(Emissions[g, t] for g in G) <= Goals[t] + Deviation[t] for t in T), "EmissionGoals")

# Emission calculations
m.addConstrs((Emissions[g, t] == E_factor_data[g][T.index(t)] * Gen[g, t] for g in G for t in T), "EmissionCalculation")

# Demand satisfaction
for t in T:
    m.addConstr(sum(Gen[g, t] for g in G) >= D_data[t]+0.12 * D_data[t], "DemandSatisfaction_" + str(t))

#fixed capacity limits for all sources in 2025
for g in G:
    m.addConstr(Gen[g, 2025] <= Fixed_GEN_data[g][T.index(2025)], f"FixedCapacityLimit_{g}_2025")

# Adjusted capacity limits for 2030
for g in G:
    if g in ['Wind', 'Solar', 'Nuclear']:
        # For Wind, Solar, and Nuclear, consider added capacity in 2030
        m.addConstr(Gen[g, 2030] <= Fixed_GEN_data[g][0] + Capacity_Increase[g, 2030], f"AdjustedCapacityLimit_{g}_2030")
    else:
        # For other sources, use fixed capacity limits in 2030
        m.addConstr(Gen[g, 2030] <= Fixed_GEN_data[g][0], f"FixedCapacityLimit_{g}_2030")

# Adjusted capacity limits for 2035, considering the capacity from 2030 and additional increase in 2035
for g in G:
    if g in ['Wind', 'Solar', 'Nuclear']:
        # For Wind, Solar, and Nuclear, consider the total capacity (2030 increase + 2035 increase)
        total_capacity_2035 = Fixed_GEN_data[g][0] + Capacity_Increase[g, 2030] + Capacity_Increase[g, 2035]
        m.addConstr(Gen[g, 2035] <= total_capacity_2035, f"TotalAdjustedCapacityLimit_{g}_2035")
    else:
        # For other sources, use fixed capacity limits in 2035
        m.addConstr(Gen[g, 2035] <= Fixed_GEN_data[g][0], f"FixedCapacityLimit_{g}_2035")


# Capacity increase constraints
for g in ['Wind', 'Solar', 'Nuclear']:
    for t in T[1:]:
                m.addConstr(Capacity_Increase[g, t] <= Capacity_Increase_Decision[g, t] * Capacity_Added[g][T.index(t)] +
                Capacity_Increase_Decision_2[g, t] * Capacity_Added[g][T.index(t)] , f"CapacityIncreaseLink_{g}_{t}")



#constraint to make sure powerplant only added if existing capacity is not enough
utilization_threshold = 1  # Define a threshold for capacity utilization
M = 1e15  

for g in ['Wind', 'Solar', 'Nuclear']:
    for t in T[1:]:  
        existing_capacity_expr = Fixed_GEN_data[g][0] + sum(Capacity_Increase[g, year] for year in [2030,2035] if year < t)

        # Binary variable indicating if capacity increase is needed
        y_gt = m.addVar(vtype=GRB.BINARY, name=f"y_{g}_{t}")
        m.addConstr(Capacity_Increase_Decision[g, t] + M*y_gt >=1)
        m.addConstr(Gen[g, t] - (utilization_threshold * existing_capacity_expr) - M * (1-y_gt) <= 0, name=f"ThresholdCheck_{g}_{t}")
        
        # Binary variable indicating if second capacity increase is needed
        y_gt2 = m.addVar(vtype=GRB.BINARY, name=f"y_{g}_{t}_2")
        m.addConstr(Capacity_Increase_Decision_2[g, t] + M * y_gt2 >= 1)
        m.addConstr(Gen[g, t] - (utilization_threshold * (existing_capacity_expr + Capacity_Added[g][T.index(t)])) - M * (1 - y_gt2) <= 0, name=f"ThresholdCheck_{g}_{t}_2")



# Phase out non-renewables
m.addConstr(Gen['Coal', 2030] == 0, "Coal_PhaseOut_2035")
m.addConstr(Gen['Oil', 2035] == 0, "Oil_PhaseOut_2035")
m.addConstr(Gen['Coal', 2035] == 0, "Coal_PhaseOut_2035")




    
    
# Optimize the model
m.optimize()

# Output results
if m.status == GRB.OPTIMAL:
    for t in T:
        print(f"Year {t}:")

        # Initialize variables to store total costs and generations
        total_cost_year = 0
        total_emissions_year = 0
        total_generation_year = 0
        total_capacity_increase_cost_year = 0  # Total cost of adding capacity for the year
        total_generation_cost_year = 0  # Total cost of generating electricity for the year
        deviation_year = Deviation[t].x

        # Print generation, emissions, and cost for each energy source
        for g in G:
            generation = Gen[g, t].x
            emissions = Emissions[g, t].x
            cost = generation * Cost_data[g][T.index(t)]

            total_generation_year += generation
            total_emissions_year += emissions
            total_generation_cost_year += cost

            print(f"  Generation ({g}): {generation} GWh")
            print(f"  Emissions ({g}): {emissions} MTCO2e")
            print(f"  Generation Cost ({g}): {cost} CAD")

        # Check and print details for each power plant type opened
        for g in ['Wind', 'Solar', 'Nuclear']:
            # First power plant
            power_plant_opened = Capacity_Increase_Decision[g, t].x
            if power_plant_opened > 0.5:  # Power plant opened in year t
                added_capacity = Capacity_Added[g][T.index(t)]
                cost_of_increase = Increase_Cost[g][T.index(t)]
                total_capacity_increase_cost_year += cost_of_increase

                print(f"  Power Plant Type Opened in {t}: {g}")
                print(f"  Added Capacity for {g} in {t}: {added_capacity} GWh")
                print(f"  Cost of Capacity Increase for {g} in {t}: {cost_of_increase} CAD")
            else:
                print(f"  No {g} Power Plant Opened in {t}")

            # Second power plant
            power_plant_opened_2 = Capacity_Increase_Decision_2[g, t].x
            if power_plant_opened_2 > 0.5:  # Second power plant opened in year t
                added_capacity = Capacity_Added[g][T.index(t)]
                cost_of_increase = Increase_Cost[g][T.index(t)]
                total_capacity_increase_cost_year += cost_of_increase

                print(f"  Second Power Plant Type Opened in {t}: {g}")
                print(f"  Added Capacity for {g} in {t}: {added_capacity} GWh")
                print(f"  Cost of Capacity Increase for {g} in {t}: {cost_of_increase} CAD")
            else:
                print(f"  No Second {g} Power Plant Opened in {t}")

        # Calculate and print total available capacity for Wind, Solar, and Nuclear
        for g in ['Wind', 'Solar', 'Nuclear']:
            total_capacity = Fixed_GEN_data[g][0]
            for year in T:
                if year <= t:
                    added_capacity = Capacity_Increase_Decision[g, year].x * Capacity_Added[g][T.index(year)]
                    added_capacity += Capacity_Increase_Decision_2[g, year].x * Capacity_Added[g][T.index(year)]
                    total_capacity += added_capacity
            print(f"  Total Available Capacity for {g} in {t}: {total_capacity} GWh")

        # Print total costs and generations
        total_cost_year = total_generation_cost_year + total_capacity_increase_cost_year
        print(f"Total Generation Cost for Year {t}: {total_generation_cost_year} CAD")
        print(f"Total Capacity Increase Cost for Year {t}: {total_capacity_increase_cost_year} CAD")
        print(f"Total Cost for Year {t}: {total_cost_year} CAD")
        print(f"Total Generation for Year {t}: {total_generation_year} GWh")
        print(f"Total Emissions for Year {t}: {total_emissions_year} MTCO2e")
        print(f"Emission Deviation for Year {t}: {deviation_year}")
else:
    print("No optimal solution found.")
# Out:
# Gurobi Optimizer version 10.0.1 build v10.0.1rc0 (mac64[x86])
#
# CPU model: Intel(R) Core(TM) i5-5250U CPU @ 1.60GHz
# Thread count: 2 physical cores, 4 logical processors, using up to 4 threads
#
# Optimize a model with 87 rows, 87 columns and 207 nonzeros
# Model fingerprint: 0x285b1983
# Variable types: 57 continuous, 30 integer (30 binary)
# Coefficient statistics:
#   Matrix range     [1e-05, 1e+15]
#   Objective range  [1e+00, 1e+10]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+15]
# Warning: Model contains large matrix coefficient range
# Warning: Model contains large objective coefficients
# Warning: Model contains large rhs
#          Consider reformulating model or setting NumericFocus parameter
#          to avoid numerical issues.
#
# ---------------------------------------------------------------------------
# Multi-objectives: starting optimization with 2 objectives ...
# ---------------------------------------------------------------------------
#
# Multi-objectives: applying initial presolve ...
# ---------------------------------------------------------------------------
#
# Presolve removed 42 rows and 24 columns
# Presolve time: 0.00s
#
# ---------------------------------------------------------------------------
# Multi-objectives: solved in 0.21 seconds (0.00 work units)
# Model is infeasible
#
# No optimal solution found.

# %% [markdown]
# ## Cost of not Satisfying Electricity Demand in Each Year
# - The model chooses to pay the penalty associated with not meeting demand in 2035 regardless of how high the penalty is. This is probably because the first priority is to minimize the deviation from zero emission as much as possible in 2035. This changed when the approach was changed from hierarchical to weighted sum with both objectives having equal weigths.

# %%
from gurobipy import Model, GRB

# Time periods
T = [2025, 2030, 2035]

# Energy sources
G = ['Wind', 'Solar', 'Oil', 'Nuclear', 'Hydro', 'Natural Gas', 'Coal', 'Geothermal']

# Emission factors for each energy source (MTCO2e/GWh) 
E_factor_data = {
    'Wind': [0.000015, 0.000015, 0.000015],
    'Solar': [0.0000445, 0.0000445, 0.0000445],
    'Oil': [0.00049, 0.00049, 0.00049],
    'Nuclear': [0.000012, 0.000012, 0.000012],
    'Hydro': [0.000024, 0.000024, 0.000024],
    'Natural Gas': [0.00049, 0.00049, 0.00049],
    'Coal': [0.00082, 0.00082, 0.00082],
    'Geothermal': [0.000038, 0.000038, 0.000038]
}


# Electricity demand for each time period (GWh) 
D_data = {2025: 611806.94, 2030: 694406.68, 2035: 787841.11} 

# Emission reduction  for each time period (#MTCO2e) 
Goals = {2025: 35.19, 2030: 28.89, 2035: 0}  #Mahrukh


# Fixed generation capacity for each time period (GWh)  
Fixed_GEN_data = {
    'Wind': [64389.48],
    'Solar': [12184.92],
    'Oil': [1379.91],
    'Nuclear': [78631.37],
    'Hydro': [402575.9],
    'Natural Gas': [106529.07],
    'Coal': [8184.54],
    'Geothermal': [8281.2]
}


# Cost data for each energy source (CAD per GWh) 
Cost_data = {
    'Wind': [80830, 80830, 80830],
    'Solar': [205500, 205500, 205500],
    'Oil': [61650, 61650, 61650],
    'Nuclear': [89050, 89050, 89050],
    'Hydro': [30140, 30140, 30140],
    'Natural Gas': [97270, 97270, 97270],
    'Coal': [83570, 83570, 83570],
    'Geothermal': [82200, 82200, 82200]
}

# Capacity increase costs for each power plant type (CAD)
Increase_Cost = {
    'Nuclear': [9.59e9, 9.59e9, 9.59e9],
    'Solar': [12.878e9, 12.878e9, 12.878e9],
    'Wind': [4.11e9, 4.11e9, 4.11e9]
}

# Capacity increase amounts for each power plant type (GWh)
Capacity_Added = {
    'Nuclear': [48180, 48180, 48180],
    'Solar': [139809.6, 139809.6, 139809.6],
    'Wind': [43800, 43800, 43800]
}
pen=183000
# Create the model
m = Model("ImprovedCanadaEnergyModel")

# Decision Variables
# Generation for each energy source and time period
Gen = m.addVars(G, T, vtype=GRB.CONTINUOUS, name="Generation")

# Emissions for each energy source and time period
Emissions = m.addVars(G, T, vtype=GRB.CONTINUOUS, name="Emissions")

# Emission deviations for each time period
Deviation = m.addVars(T, vtype=GRB.CONTINUOUS, name="Deviation")

# Decision variables for capacity increase (only for Wind, Solar, Nuclear)
Capacity_Increase = m.addVars(['Wind', 'Solar', 'Nuclear'], [2030,2035], vtype=GRB.CONTINUOUS, name="Capacity_Increase")

# Binary variables for capacity increase decision
Capacity_Increase_Decision = m.addVars(['Wind', 'Solar', 'Nuclear'],T,vtype=GRB.BINARY, name="CapacityIncreaseDecision")
Capacity_Increase_Decision_2 = m.addVars(['Wind', 'Solar', 'Nuclear'],T, vtype=GRB.BINARY, name="CapacityIncreaseDecision2")

# Objective Functions
# Objective 1: Minimize emissions deviation
m.setObjectiveN(sum(Deviation[t] for t in T), index=0, weight=1, name="Minimize_Emissions")

# Objective 2: Minimize cost 
Total_Cost = (
    sum(Cost_data[g][T.index(t)] * Gen[g, t] for g in G for t in T) +
    pen*sum((D_data[t] - sum(Gen[g, t] for g in G)) for t in T) +
    sum(Increase_Cost[g][T.index(t)] * Capacity_Increase_Decision[g, t] +Increase_Cost[g][T.index(t)] * Capacity_Increase_Decision_2[g, t] for g in ['Wind', 'Solar', 'Nuclear'] for t in T)  # Fixed opening cost
)
m.setObjectiveN(Total_Cost, index=1, weight=1, name="Minimize_Cost")

# Constraints
# Emission goals
m.addConstrs((sum(Emissions[g, t] for g in G) <= Goals[t] + Deviation[t] for t in T), "EmissionGoals")

# Emission calculations
m.addConstrs((Emissions[g, t] == E_factor_data[g][T.index(t)] * Gen[g, t] for g in G for t in T), "EmissionCalculation")

# Demand satisfaction
for t in T:
    m.addConstr(sum(Gen[g, t] for g in G) <= D_data[t], "DemandSatisfaction_" + str(t))

#fixed capacity limits for all sources in 2025
for g in G:
    m.addConstr(Gen[g, 2025] <= Fixed_GEN_data[g][T.index(2025)], f"FixedCapacityLimit_{g}_2025")

# Adjusted capacity limits for 2030
for g in G:
    if g in ['Wind', 'Solar', 'Nuclear']:
        # For Wind, Solar, and Nuclear, consider added capacity in 2030
        m.addConstr(Gen[g, 2030] <= Fixed_GEN_data[g][0] + Capacity_Increase[g, 2030], f"AdjustedCapacityLimit_{g}_2030")
    else:
        # For other sources, use fixed capacity limits in 2030
        m.addConstr(Gen[g, 2030] <= Fixed_GEN_data[g][0], f"FixedCapacityLimit_{g}_2030")

# Adjusted capacity limits for 2035, considering the capacity from 2030 and additional increase in 2035
for g in G:
    if g in ['Wind', 'Solar', 'Nuclear']:
        # For Wind, Solar, and Nuclear, consider the total capacity (2030 increase + 2035 increase)
        total_capacity_2035 = Fixed_GEN_data[g][0] + Capacity_Increase[g, 2030] + Capacity_Increase[g, 2035]
        m.addConstr(Gen[g, 2035] <= total_capacity_2035, f"TotalAdjustedCapacityLimit_{g}_2035")
    else:
        # For other sources, use fixed capacity limits in 2035
        m.addConstr(Gen[g, 2035] <= Fixed_GEN_data[g][0], f"FixedCapacityLimit_{g}_2035")


# Capacity increase constraints
for g in ['Wind', 'Solar', 'Nuclear']:
    for t in T[1:]:
                m.addConstr(Capacity_Increase[g, t] <= Capacity_Increase_Decision[g, t] * Capacity_Added[g][T.index(t)] +
                Capacity_Increase_Decision_2[g, t] * Capacity_Added[g][T.index(t)] , f"CapacityIncreaseLink_{g}_{t}")



#constraint to make sure powerplant only added if existing capacity is not enough
utilization_threshold = 1  # Define a threshold for capacity utilization
M = 1e15  

for g in ['Wind', 'Solar', 'Nuclear']:
    for t in T[1:]:  
        existing_capacity_expr = Fixed_GEN_data[g][0] + sum(Capacity_Increase[g, year] for year in [2030,2035] if year < t)

        # Binary variable indicating if capacity increase is needed
        y_gt = m.addVar(vtype=GRB.BINARY, name=f"y_{g}_{t}")
        m.addConstr(Capacity_Increase_Decision[g, t] + M*y_gt >=1)
        m.addConstr(Gen[g, t] - (utilization_threshold * existing_capacity_expr) - M * (1-y_gt) <= 0, name=f"ThresholdCheck_{g}_{t}")
        
        # Binary variable indicating if second capacity increase is needed
        y_gt2 = m.addVar(vtype=GRB.BINARY, name=f"y_{g}_{t}_2")
        m.addConstr(Capacity_Increase_Decision_2[g, t] + M * y_gt2 >= 1)
        m.addConstr(Gen[g, t] - (utilization_threshold * (existing_capacity_expr + Capacity_Added[g][T.index(t)])) - M * (1 - y_gt2) <= 0, name=f"ThresholdCheck_{g}_{t}_2")



# Phase out non-renewables
m.addConstr(Gen['Coal', 2030] == 0, "Coal_PhaseOut_2035")
m.addConstr(Gen['Oil', 2035] == 0, "Oil_PhaseOut_2035")
m.addConstr(Gen['Coal', 2035] == 0, "Coal_PhaseOut_2035")


    
    
# Optimize the model
m.optimize()

# Output results
if m.status == GRB.OPTIMAL:
    for t in T:
        print(f"Year {t}:")

        # Initialize variables to store total costs and generations
        total_cost_year = 0
        total_emissions_year = 0
        total_generation_year = 0
        total_capacity_increase_cost_year = 0  # Total cost of adding capacity for the year
        total_generation_cost_year = 0  # Total cost of generating electricity for the year
        deviation_year = Deviation[t].x

        # Print generation, emissions, and cost for each energy source
        for g in G:
            generation = Gen[g, t].x
            emissions = Emissions[g, t].x
            cost = generation * Cost_data[g][T.index(t)]

            total_generation_year += generation
            total_emissions_year += emissions
            total_generation_cost_year += cost

            print(f"  Generation ({g}): {generation} GWh")
            print(f"  Emissions ({g}): {emissions} MTCO2e")
            print(f"  Generation Cost ({g}): {cost} CAD")

        # Check and print details for each power plant type opened
        for g in ['Wind', 'Solar', 'Nuclear']:
            # First power plant
            power_plant_opened = Capacity_Increase_Decision[g, t].x
            if power_plant_opened > 0.5:  # Power plant opened in year t
                added_capacity = Capacity_Added[g][T.index(t)]
                cost_of_increase = Increase_Cost[g][T.index(t)]
                total_capacity_increase_cost_year += cost_of_increase

                print(f"  Power Plant Type Opened in {t}: {g}")
                print(f"  Added Capacity for {g} in {t}: {added_capacity} GWh")
                print(f"  Cost of Capacity Increase for {g} in {t}: {cost_of_increase} CAD")
            else:
                print(f"  No {g} Power Plant Opened in {t}")

            # Second power plant
            power_plant_opened_2 = Capacity_Increase_Decision_2[g, t].x
            if power_plant_opened_2 > 0.5:  # Second power plant opened in year t
                added_capacity = Capacity_Added[g][T.index(t)]
                cost_of_increase = Increase_Cost[g][T.index(t)]
                total_capacity_increase_cost_year += cost_of_increase

                print(f"  Second Power Plant Type Opened in {t}: {g}")
                print(f"  Added Capacity for {g} in {t}: {added_capacity} GWh")
                print(f"  Cost of Capacity Increase for {g} in {t}: {cost_of_increase} CAD")
            else:
                print(f"  No Second {g} Power Plant Opened in {t}")

        # Calculate and print total available capacity for Wind, Solar, and Nuclear
        for g in ['Wind', 'Solar', 'Nuclear']:
            total_capacity = Fixed_GEN_data[g][0]
            for year in T:
                if year <= t:
                    added_capacity = Capacity_Increase_Decision[g, year].x * Capacity_Added[g][T.index(year)]
                    added_capacity += Capacity_Increase_Decision_2[g, year].x * Capacity_Added[g][T.index(year)]
                    total_capacity += added_capacity
            print(f"  Total Available Capacity for {g} in {t}: {total_capacity} GWh")

        # Print total costs and generations
        total_cost_year = total_generation_cost_year + total_capacity_increase_cost_year
        print(f"Total Generation Cost for Year {t}: {total_generation_cost_year} CAD")
        print(f"Total Capacity Increase Cost for Year {t}: {total_capacity_increase_cost_year} CAD")
        print(f"Total Cost for Year {t}: {total_cost_year} CAD")
        print(f"Total Generation for Year {t}: {total_generation_year} GWh")
        print(f"Total Emissions for Year {t}: {total_emissions_year} MTCO2e")
        print(f"Emission Deviation for Year {t}: {deviation_year}")
else:
    print("No optimal solution found.")
# print demand not satisfied
for t in T:
    print(f"Year {t}:")
    print(f"  Demand Not Satisfied: {D_data[t] - sum(Gen[g, t].x for g in G)} GWh")
# Out:
# Gurobi Optimizer version 10.0.1 build v10.0.1rc0 (mac64[x86])
#
# CPU model: Intel(R) Core(TM) i5-5250U CPU @ 1.60GHz
# Thread count: 2 physical cores, 4 logical processors, using up to 4 threads
#
# Optimize a model with 87 rows, 87 columns and 207 nonzeros
# Model fingerprint: 0x9431d02d
# Variable types: 57 continuous, 30 integer (30 binary)
# Coefficient statistics:
#   Matrix range     [1e-05, 1e+15]
#   Objective range  [1e+00, 1e+10]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+15]
# Warning: Model contains large matrix coefficient range
# Warning: Model contains large objective coefficients
# Warning: Model contains large rhs
#          Consider reformulating model or setting NumericFocus parameter
#          to avoid numerical issues.
#
# ---------------------------------------------------------------------------
# Multi-objectives: starting optimization with 2 objectives (1 combined) ...
# ---------------------------------------------------------------------------
# ---------------------------------------------------------------------------
#
# Multi-objectives: optimize objective 1 (weighted) ...
# ---------------------------------------------------------------------------
#
# Optimize a model with 87 rows, 87 columns and 207 nonzeros
# Model fingerprint: 0xd31836c0
# Variable types: 57 continuous, 30 integer (30 binary)
# Coefficient statistics:
#   Matrix range     [1e-05, 1e+15]
#   Objective range  [1e+00, 1e+10]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+15]
# Warning: Model contains large matrix coefficient range
# Warning: Model contains large objective coefficients
# Warning: Model contains large rhs
#          Consider reformulating model or setting NumericFocus parameter
#          to avoid numerical issues.
# Found heuristic solution: objective 3.832120e+11
# Presolve removed 76 rows and 69 columns
# Presolve time: 0.00s
# Presolved: 11 rows, 18 columns, 44 nonzeros
# Found heuristic solution: objective 2.364736e+11
# Variable types: 10 continuous, 8 integer (8 binary)
#
# Root relaxation: objective 1.253371e+11, 8 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 1.2534e+11    0    1 2.3647e+11 1.2534e+11  47.0%     -    0s
# H    0     0                    1.256691e+11 1.2534e+11  0.26%     -    0s
# H    0     0                    1.256440e+11 1.2534e+11  0.24%     -    0s
#      0     0     cutoff    0      1.2564e+11 1.2564e+11  0.00%     -    0s
#
# Cutting planes:
#   Relax-and-lift: 1
#
# Explored 1 nodes (11 simplex iterations) in 0.29 seconds (0.00 work units)
# Thread count was 4 (of 4 available processors)
#
# Solution count 4: 1.25644e+11 1.25669e+11 2.36474e+11 3.83212e+11
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.256440183920e+11, best bound 1.256440183920e+11, gap 0.0000%
#
# ---------------------------------------------------------------------------
# Multi-objectives: solved in 0.31 seconds (0.00 work units), solution count 3
#
# Year 2025:
#   Generation (Wind): 64389.48 GWh
#   Emissions (Wind): 0.9658422000000001 MTCO2e
#   Generation Cost (Wind): 5204601668.400001 CAD
#   Generation (Solar): 0.0 GWh
#   Emissions (Solar): 0.0 MTCO2e
#   Generation Cost (Solar): 0.0 CAD
#   Generation (Oil): 1379.91 GWh
#   Emissions (Oil): 0.6761559 MTCO2e
#   Generation Cost (Oil): 85071451.5 CAD
#   Generation (Nuclear): 78631.37 GWh
#   Emissions (Nuclear): 0.94357644 MTCO2e
#   Generation Cost (Nuclear): 7002123498.5 CAD
#   Generation (Hydro): 402575.9 GWh
#   Emissions (Hydro): 9.661821600000001 MTCO2e
#   Generation Cost (Hydro): 12133637626.0 CAD
#   Generation (Natural Gas): 48364.53999999991 GWh
#   Emissions (Natural Gas): 23.698624599999956 MTCO2e
#   Generation Cost (Natural Gas): 4704418805.799992 CAD
#   Generation (Coal): 8184.54 GWh
#   Emissions (Coal): 6.7113228 MTCO2e
#   Generation Cost (Coal): 683982007.8 CAD
#   Generation (Geothermal): 8281.2 GWh
#   Emissions (Geothermal): 0.31468560000000007 MTCO2e
#   Generation Cost (Geothermal): 680714640.0000001 CAD
#   No Wind Power Plant Opened in 2025
#   No Second Wind Power Plant Opened in 2025
#   No Solar Power Plant Opened in 2025
#   No Second Solar Power Plant Opened in 2025
#   No Nuclear Power Plant Opened in 2025
#   No Second Nuclear Power Plant Opened in 2025
#   Total Available Capacity for Wind in 2025: 64389.48 GWh
#   Total Available Capacity for Solar in 2025: 12184.92 GWh
#   Total Available Capacity for Nuclear in 2025: 78631.37 GWh
# Total Generation Cost for Year 2025: 30494549697.999992 CAD
# Total Capacity Increase Cost for Year 2025: 0 CAD
# Total Cost for Year 2025: 30494549697.999992 CAD
# Total Generation for Year 2025: 611806.94 GWh
# Total Emissions for Year 2025: 42.972029139999954 MTCO2e
# Emission Deviation for Year 2025: 7.782029139999958
# Year 2030:
#   Generation (Wind): 151989.48 GWh
#   Emissions (Wind): 2.2798422 MTCO2e
#   Generation Cost (Wind): 12285309668.400002 CAD
#   Generation (Solar): 0.0 GWh
#   Emissions (Solar): 0.0 MTCO2e
#   Generation Cost (Solar): 0.0 CAD
#   Generation (Oil): 1379.91 GWh
#   Emissions (Oil): 0.6761559 MTCO2e
#   Generation Cost (Oil): 85071451.5 CAD
#   Generation (Nuclear): 78631.37 GWh
#   Emissions (Nuclear): 0.94357644 MTCO2e
#   Generation Cost (Nuclear): 7002123498.5 CAD
#   Generation (Hydro): 402575.9 GWh
#   Emissions (Hydro): 9.661821600000001 MTCO2e
#   Generation Cost (Hydro): 12133637626.0 CAD
#   Generation (Natural Gas): 51548.81999999998 GWh
#   Emissions (Natural Gas): 25.25892179999999 MTCO2e
#   Generation Cost (Natural Gas): 5014153721.399998 CAD
#   Generation (Coal): 0.0 GWh
#   Emissions (Coal): 0.0 MTCO2e
#   Generation Cost (Coal): 0.0 CAD
#   Generation (Geothermal): 8281.2 GWh
#   Emissions (Geothermal): 0.31468560000000007 MTCO2e
#   Generation Cost (Geothermal): 680714640.0000001 CAD
#   Power Plant Type Opened in 2030: Wind
#   Added Capacity for Wind in 2030: 43800 GWh
#   Cost of Capacity Increase for Wind in 2030: 4110000000.0 CAD
#   Second Power Plant Type Opened in 2030: Wind
#   Added Capacity for Wind in 2030: 43800 GWh
#   Cost of Capacity Increase for Wind in 2030: 4110000000.0 CAD
#   No Solar Power Plant Opened in 2030
#   No Second Solar Power Plant Opened in 2030
#   No Nuclear Power Plant Opened in 2030
#   No Second Nuclear Power Plant Opened in 2030
#   Total Available Capacity for Wind in 2030: 151989.48 GWh
#   Total Available Capacity for Solar in 2030: 12184.92 GWh
#   Total Available Capacity for Nuclear in 2030: 78631.37 GWh
# Total Generation Cost for Year 2030: 37201010605.8 CAD
# Total Capacity Increase Cost for Year 2030: 8220000000.0 CAD
# Total Cost for Year 2030: 45421010605.8 CAD
# Total Generation for Year 2030: 694406.6799999999 GWh
# Total Emissions for Year 2030: 39.135003539999985 MTCO2e
# Emission Deviation for Year 2030: 10.245003539999985
# Year 2035:
#   Generation (Wind): 195789.48 GWh
#   Emissions (Wind): 2.9368422 MTCO2e
#   Generation Cost (Wind): 15825663668.400002 CAD
#   Generation (Solar): 0.0 GWh
#   Emissions (Solar): 0.0 MTCO2e
#   Generation Cost (Solar): 0.0 CAD
#   Generation (Oil): 0.0 GWh
#   Emissions (Oil): 0.0 MTCO2e
#   Generation Cost (Oil): 0.0 CAD
#   Generation (Nuclear): 78631.37 GWh
#   Emissions (Nuclear): 0.94357644 MTCO2e
#   Generation Cost (Nuclear): 7002123498.5 CAD
#   Generation (Hydro): 402575.9 GWh
#   Emissions (Hydro): 9.661821600000001 MTCO2e
#   Generation Cost (Hydro): 12133637626.0 CAD
#   Generation (Natural Gas): 102563.15999999995 GWh
#   Emissions (Natural Gas): 50.25594839999997 MTCO2e
#   Generation Cost (Natural Gas): 9976318573.199995 CAD
#   Generation (Coal): 0.0 GWh
#   Emissions (Coal): 0.0 MTCO2e
#   Generation Cost (Coal): 0.0 CAD
#   Generation (Geothermal): 8281.2 GWh
#   Emissions (Geothermal): 0.31468560000000007 MTCO2e
#   Generation Cost (Geothermal): 680714640.0000001 CAD
#   Power Plant Type Opened in 2035: Wind
#   Added Capacity for Wind in 2035: 43800 GWh
#   Cost of Capacity Increase for Wind in 2035: 4110000000.0 CAD
#   No Second Wind Power Plant Opened in 2035
#   No Solar Power Plant Opened in 2035
#   No Second Solar Power Plant Opened in 2035
#   No Nuclear Power Plant Opened in 2035
#   No Second Nuclear Power Plant Opened in 2035
#   Total Available Capacity for Wind in 2035: 195789.48 GWh
#   Total Available Capacity for Solar in 2035: 12184.92 GWh
#   Total Available Capacity for Nuclear in 2035: 78631.37 GWh
# Total Generation Cost for Year 2035: 45618458006.1 CAD
# Total Capacity Increase Cost for Year 2035: 4110000000.0 CAD
# Total Cost for Year 2035: 49728458006.1 CAD
# Total Generation for Year 2035: 787841.1099999999 GWh
# Total Emissions for Year 2035: 64.11287423999998 MTCO2e
# Emission Deviation for Year 2035: 64.11287423999998
# Year 2025:
#   Demand Not Satisfied: 0.0 GWh
# Year 2030:
#   Demand Not Satisfied: 1.1641532182693481e-10 GWh
# Year 2035:
#   Demand Not Satisfied: 1.1641532182693481e-10 GWh

# %% [markdown]
# ## Weighted Sum Approach

# %%
from gurobipy import Model, GRB

# Time periods
T = [2025, 2030, 2035]

# Energy sources
G = ['Wind', 'Solar', 'Oil', 'Nuclear', 'Hydro', 'Natural Gas', 'Coal', 'Geothermal']

# Emission factors for each energy source (MTCO2e/GWh) 
E_factor_data = {
    'Wind': [0.000015, 0.000015, 0.000015],
    'Solar': [0.0000445, 0.0000445, 0.0000445],
    'Oil': [0.00049, 0.00049, 0.00049],
    'Nuclear': [0.000012, 0.000012, 0.000012],
    'Hydro': [0.000024, 0.000024, 0.000024],
    'Natural Gas': [0.00049, 0.00049, 0.00049],
    'Coal': [0.00082, 0.00082, 0.00082],
    'Geothermal': [0.000038, 0.000038, 0.000038]
}

# Electricity demand for each time period (GWh) 
D_data = {2025: 611806.94, 2030: 694406.68, 2035: 787841.11} 

# Emission reduction  for each time period (#MTCO2e) 
Goals = {2025: 35.19, 2030: 28.89, 2035: 0}  


# Fixed generation capacity for each time period (GWh)  
Fixed_GEN_data = {
    'Wind': [64389.48],
    'Solar': [12184.92],
    'Oil': [1379.91],
    'Nuclear': [78631.37],
    'Hydro': [402575.9],
    'Natural Gas': [106529.07],
    'Coal': [8184.54],
    'Geothermal': [8281.2]
}


# Cost data for each energy source (CAD per GWh) 
Cost_data = {
    'Wind': [80830, 80830, 80830],
    'Solar': [205500, 205500, 205500],
    'Oil': [61650, 61650, 61650],
    'Nuclear': [89050, 89050, 89050],
    'Hydro': [30140, 30140, 30140],
    'Natural Gas': [97270, 97270, 97270],
    'Coal': [83570, 83570, 83570],
    'Geothermal': [82200, 82200, 82200]
}

# Capacity increase costs for each power plant type (CAD)
Increase_Cost = {
    'Nuclear': [9.59e9, 9.59e9, 9.59e9],
    'Solar': [12.878e9, 12.878e9, 12.878e9],
    'Wind': [4.11e9, 4.11e9, 4.11e9]
}

# Capacity increase amounts for each power plant type (GWh)
Capacity_Added = {
    'Nuclear': [48180, 48180, 48180],
    'Solar': [139809.6, 139809.6, 139809.6],
    'Wind': [43800, 43800, 43800]
}

# Create the model
m = Model("ImprovedCanadaEnergyModel")

# Decision Variables
# Generation for each energy source and time period
Gen = m.addVars(G, T, vtype=GRB.CONTINUOUS, name="Generation")

# Emissions for each energy source and time period
Emissions = m.addVars(G, T, vtype=GRB.CONTINUOUS, name="Emissions")

# Emission deviations for each time period
Deviation = m.addVars(T, vtype=GRB.CONTINUOUS, name="Deviation")

# Decision variables for capacity increase (only for Wind, Solar, Nuclear)
Capacity_Increase = m.addVars(['Wind', 'Solar', 'Nuclear'], T, vtype=GRB.CONTINUOUS, name="Capacity_Increase")

# Binary variables for capacity increase decision
Capacity_Increase_Decision = m.addVars(['Wind', 'Solar', 'Nuclear'],T,vtype=GRB.BINARY, name="CapacityIncreaseDecision")
Capacity_Increase_Decision_2 = m.addVars(['Wind', 'Solar', 'Nuclear'],T, vtype=GRB.BINARY, name="CapacityIncreaseDecision2")

# Objective Functions
# Objective 1: Minimize emissions deviation
m.setObjectiveN(sum(Deviation[t] for t in T), index=0, weight=0.5, name="Minimize_Emissions")

# Objective 2: Minimize cost 
Total_Cost = (
    sum(Cost_data[g][T.index(t)] * Gen[g, t] for g in G for t in T) +
    sum(Increase_Cost[g][T.index(t)] * Capacity_Increase_Decision[g, t] +Increase_Cost[g][T.index(t)] * Capacity_Increase_Decision_2[g, t] for g in ['Wind', 'Solar', 'Nuclear'] for t in T)  # Fixed opening cost
)
m.setObjectiveN(Total_Cost, index=1, weight=0.5, name="Minimize_Cost")

# Constraints
# Emission goals
m.addConstrs((sum(Emissions[g, t] for g in G) <= Goals[t] + Deviation[t] for t in T), "EmissionGoals")

# Emission calculations
m.addConstrs((Emissions[g, t] == E_factor_data[g][T.index(t)] * Gen[g, t] for g in G for t in T), "EmissionCalculation")

# Demand satisfaction
for t in T:
    m.addConstr(sum(Gen[g, t] for g in G) >= D_data[t], "DemandSatisfaction_" + str(t))

#fixed capacity limits for all sources in 2025
for g in G:
    m.addConstr(Gen[g, 2025] <= Fixed_GEN_data[g][T.index(2025)], f"FixedCapacityLimit_{g}_2025")

# Adjusted capacity limits for 2030
for g in G:
    if g in ['Wind', 'Solar', 'Nuclear']:
        # For Wind, Solar, and Nuclear, consider added capacity in 2030
        m.addConstr(Gen[g, 2030] <= Fixed_GEN_data[g][0] + Capacity_Increase[g, 2030], f"AdjustedCapacityLimit_{g}_2030")
    else:
        # For other sources, use fixed capacity limits in 2030
        m.addConstr(Gen[g, 2030] <= Fixed_GEN_data[g][0], f"FixedCapacityLimit_{g}_2030")

# Adjusted capacity limits for 2035, considering the capacity from 2030 and additional increase in 2035
for g in G:
    if g in ['Wind', 'Solar', 'Nuclear']:
        # For Wind, Solar, and Nuclear, consider the total capacity (2030 increase + 2035 increase)
        total_capacity_2035 = Fixed_GEN_data[g][0] + Capacity_Increase[g, 2030] + Capacity_Increase[g, 2035]
        m.addConstr(Gen[g, 2035] <= total_capacity_2035, f"TotalAdjustedCapacityLimit_{g}_2035")
    else:
        # For other sources, use fixed capacity limits in 2035
        m.addConstr(Gen[g, 2035] <= Fixed_GEN_data[g][0], f"FixedCapacityLimit_{g}_2035")


# Capacity increase constraints
for g in ['Wind', 'Solar', 'Nuclear']:
    for t in T[1:]:
                m.addConstr(Capacity_Increase[g, t] <= Capacity_Increase_Decision[g, t] * Capacity_Added[g][T.index(t)] +
                Capacity_Increase_Decision_2[g, t] * Capacity_Added[g][T.index(t)] , f"CapacityIncreaseLink_{g}_{t}")



#constraint to make sure powerplant only added if existing capacity is not enough
utilization_threshold = 1  # Define a threshold for capacity utilization
M = 1e15  

for g in ['Wind', 'Solar', 'Nuclear']:
    for t in T[1:]:  
        existing_capacity_expr = Fixed_GEN_data[g][0] + sum(Capacity_Increase[g, year] for year in T if year < t)

        # Binary variable indicating if capacity increase is needed
        y_gt = m.addVar(vtype=GRB.BINARY, name=f"y_{g}_{t}")
        m.addConstr(Capacity_Increase_Decision[g, t] + M*y_gt >=1)
        m.addConstr(Gen[g, t] - (utilization_threshold * existing_capacity_expr) - M * (1-y_gt) <= 0, name=f"ThresholdCheck_{g}_{t}")
        
        # Binary variable indicating if second capacity increase is needed
        y_gt2 = m.addVar(vtype=GRB.BINARY, name=f"y_{g}_{t}_2")
        m.addConstr(Capacity_Increase_Decision_2[g, t] + M * y_gt2 >= 1)
        m.addConstr(Gen[g, t] - (utilization_threshold * (existing_capacity_expr + Capacity_Added[g][T.index(t)])) - M * (1 - y_gt2) <= 0, name=f"ThresholdCheck_{g}_{t}_2")
#constraint capacity incease 2025 for renewables is 0
m.addConstr(Capacity_Increase['Wind', 2025] == 0)
m.addConstr(Capacity_Increase['Solar', 2025] == 0)
m.addConstr(Capacity_Increase['Nuclear', 2025] == 0)


# Phase out non-renewables
m.addConstr(Gen['Coal', 2030] == 0, "Coal_PhaseOut_2035")
m.addConstr(Gen['Oil', 2035] == 0, "Oil_PhaseOut_2035")
m.addConstr(Gen['Coal', 2035] == 0, "Coal_PhaseOut_2035")



    
    
# Optimize the model
m.optimize()

# Output results
if m.status == GRB.OPTIMAL:
    for t in T:
        print(f"Year {t}:")

        # Initialize variables to store total costs and generations
        total_cost_year = 0
        total_emissions_year = 0
        total_generation_year = 0
        total_capacity_increase_cost_year = 0  # Total cost of adding capacity for the year
        total_generation_cost_year = 0  # Total cost of generating electricity for the year
        deviation_year = Deviation[t].x

        # Print generation, emissions, and cost for each energy source
        for g in G:
            generation = Gen[g, t].x
            emissions = Emissions[g, t].x
            cost = generation * Cost_data[g][T.index(t)]

            total_generation_year += generation
            total_emissions_year += emissions
            total_generation_cost_year += cost

            print(f"  Generation ({g}): {generation} GWh")
            print(f"  Emissions ({g}): {emissions} MTCO2e")
            print(f"  Generation Cost ({g}): {cost} CAD")

        # Check and print details for each power plant type opened
        for g in ['Wind', 'Solar', 'Nuclear']:
            # First power plant
            power_plant_opened = Capacity_Increase_Decision[g, t].x
            if power_plant_opened > 0.5:  # Power plant opened in year t
                added_capacity = Capacity_Added[g][T.index(t)]
                cost_of_increase = Increase_Cost[g][T.index(t)]
                total_capacity_increase_cost_year += cost_of_increase

                print(f"  Power Plant Type Opened in {t}: {g}")
                print(f"  Added Capacity for {g} in {t}: {added_capacity} GWh")
                print(f"  Cost of Capacity Increase for {g} in {t}: {cost_of_increase} CAD")
            else:
                print(f"  No {g} Power Plant Opened in {t}")

            # Second power plant
            power_plant_opened_2 = Capacity_Increase_Decision_2[g, t].x
            if power_plant_opened_2 > 0.5:  # Second power plant opened in year t
                added_capacity = Capacity_Added[g][T.index(t)]
                cost_of_increase = Increase_Cost[g][T.index(t)]
                total_capacity_increase_cost_year += cost_of_increase

                print(f"  Second Power Plant Type Opened in {t}: {g}")
                print(f"  Added Capacity for {g} in {t}: {added_capacity} GWh")
                print(f"  Cost of Capacity Increase for {g} in {t}: {cost_of_increase} CAD")
            else:
                print(f"  No Second {g} Power Plant Opened in {t}")

        # Calculate and print total available capacity for Wind, Solar, and Nuclear
        for g in ['Wind', 'Solar', 'Nuclear']:
            total_capacity = Fixed_GEN_data[g][0]
            for year in T:
                if year <= t:
                    added_capacity = Capacity_Increase_Decision[g, year].x * Capacity_Added[g][T.index(year)]
                    added_capacity += Capacity_Increase_Decision_2[g, year].x * Capacity_Added[g][T.index(year)]
                    total_capacity += added_capacity
            print(f"  Total Available Capacity for {g} in {t}: {total_capacity} GWh")

        # Print total costs and generations
        total_cost_year = total_generation_cost_year + total_capacity_increase_cost_year
        print(f"Total Generation Cost for Year {t}: {total_generation_cost_year} CAD")
        print(f"Total Capacity Increase Cost for Year {t}: {total_capacity_increase_cost_year} CAD")
        print(f"Total Cost for Year {t}: {total_cost_year} CAD")
        print(f"Total Generation for Year {t}: {total_generation_year} GWh")
        print(f"Total Emissions for Year {t}: {total_emissions_year} MTCO2e")
        print(f"Emission Deviation for Year {t}: {deviation_year}")
else:
    print("No optimal solution found.")
# Out:
# Gurobi Optimizer version 10.0.1 build v10.0.1rc0 (mac64[x86])
#
# CPU model: Intel(R) Core(TM) i5-5250U CPU @ 1.60GHz
# Thread count: 2 physical cores, 4 logical processors, using up to 4 threads
#
# Optimize a model with 90 rows, 90 columns and 222 nonzeros
# Model fingerprint: 0x3a81ce4c
# Variable types: 60 continuous, 30 integer (30 binary)
# Coefficient statistics:
#   Matrix range     [1e-05, 1e+15]
#   Objective range  [1e+00, 1e+10]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+15]
# Warning: Model contains large matrix coefficient range
# Warning: Model contains large objective coefficients
# Warning: Model contains large rhs
#          Consider reformulating model or setting NumericFocus parameter
#          to avoid numerical issues.
#
# ---------------------------------------------------------------------------
# Multi-objectives: starting optimization with 2 objectives (1 combined) ...
# ---------------------------------------------------------------------------
# ---------------------------------------------------------------------------
#
# Multi-objectives: optimize objective 1 (weighted) ...
# ---------------------------------------------------------------------------
#
# Optimize a model with 90 rows, 90 columns and 222 nonzeros
# Model fingerprint: 0x3b9db92b
# Variable types: 60 continuous, 30 integer (30 binary)
# Coefficient statistics:
#   Matrix range     [1e-05, 1e+15]
#   Objective range  [5e-01, 6e+09]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+15]
# Warning: Model contains large matrix coefficient range
# Warning: Model contains large objective coefficients
# Warning: Model contains large rhs
#          Consider reformulating model or setting NumericFocus parameter
#          to avoid numerical issues.
# Found heuristic solution: objective 1.798493e+11
# Presolve removed 72 rows and 63 columns
# Presolve time: 0.00s
# Presolved: 18 rows, 27 columns, 70 nonzeros
# Found heuristic solution: objective 1.587171e+11
# Variable types: 14 continuous, 13 integer (12 binary)
#
# Root relaxation: objective 6.266854e+10, 8 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 6.2669e+10    0    2 1.5872e+11 6.2669e+10  60.5%     -    0s
# H    0     0                    6.285461e+10 6.2669e+10  0.30%     -    0s
# *    0     0               0    6.282201e+10 6.2822e+10  0.00%     -    0s
#
# Explored 1 nodes (10 simplex iterations) in 0.15 seconds (0.00 work units)
# Thread count was 4 (of 4 available processors)
#
# Solution count 3: 6.2822e+10 1.58717e+11 1.79849e+11
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 6.282200919602e+10, best bound 6.282200919602e+10, gap 0.0000%
#
# ---------------------------------------------------------------------------
# Multi-objectives: solved in 0.19 seconds (0.00 work units), solution count 3
#
# Year 2025:
#   Generation (Wind): 64389.48 GWh
#   Emissions (Wind): 0.9658422000000001 MTCO2e
#   Generation Cost (Wind): 5204601668.400001 CAD
#   Generation (Solar): 0.0 GWh
#   Emissions (Solar): 0.0 MTCO2e
#   Generation Cost (Solar): 0.0 CAD
#   Generation (Oil): 1379.91 GWh
#   Emissions (Oil): 0.6761559 MTCO2e
#   Generation Cost (Oil): 85071451.5 CAD
#   Generation (Nuclear): 78631.37 GWh
#   Emissions (Nuclear): 0.94357644 MTCO2e
#   Generation Cost (Nuclear): 7002123498.5 CAD
#   Generation (Hydro): 402575.9 GWh
#   Emissions (Hydro): 9.661821600000001 MTCO2e
#   Generation Cost (Hydro): 12133637626.0 CAD
#   Generation (Natural Gas): 48364.539999999906 GWh
#   Emissions (Natural Gas): 23.698624599999953 MTCO2e
#   Generation Cost (Natural Gas): 4704418805.799991 CAD
#   Generation (Coal): 8184.54 GWh
#   Emissions (Coal): 6.7113228 MTCO2e
#   Generation Cost (Coal): 683982007.8 CAD
#   Generation (Geothermal): 8281.2 GWh
#   Emissions (Geothermal): 0.31468560000000007 MTCO2e
#   Generation Cost (Geothermal): 680714640.0000001 CAD
#   No Wind Power Plant Opened in 2025
#   No Second Wind Power Plant Opened in 2025
#   No Solar Power Plant Opened in 2025
#   No Second Solar Power Plant Opened in 2025
#   No Nuclear Power Plant Opened in 2025
#   No Second Nuclear Power Plant Opened in 2025
#   Total Available Capacity for Wind in 2025: 64389.48 GWh
#   Total Available Capacity for Solar in 2025: 12184.92 GWh
#   Total Available Capacity for Nuclear in 2025: 78631.37 GWh
# Total Generation Cost for Year 2025: 30494549697.999992 CAD
# Total Capacity Increase Cost for Year 2025: 0 CAD
# Total Cost for Year 2025: 30494549697.999992 CAD
# Total Generation for Year 2025: 611806.94 GWh
# Total Emissions for Year 2025: 42.97202913999995 MTCO2e
# Emission Deviation for Year 2025: 7.782029139999953
# Year 2030:
#   Generation (Wind): 151989.48 GWh
#   Emissions (Wind): 2.2798422 MTCO2e
#   Generation Cost (Wind): 12285309668.400002 CAD
#   Generation (Solar): 0.0 GWh
#   Emissions (Solar): 0.0 MTCO2e
#   Generation Cost (Solar): 0.0 CAD
#   Generation (Oil): 1379.91 GWh
#   Emissions (Oil): 0.6761559 MTCO2e
#   Generation Cost (Oil): 85071451.5 CAD
#   Generation (Nuclear): 78631.37 GWh
#   Emissions (Nuclear): 0.94357644 MTCO2e
#   Generation Cost (Nuclear): 7002123498.5 CAD
#   Generation (Hydro): 402575.9 GWh
#   Emissions (Hydro): 9.661821600000001 MTCO2e
#   Generation Cost (Hydro): 12133637626.0 CAD
#   Generation (Natural Gas): 51548.81999999998 GWh
#   Emissions (Natural Gas): 25.25892179999999 MTCO2e
#   Generation Cost (Natural Gas): 5014153721.399998 CAD
#   Generation (Coal): 0.0 GWh
#   Emissions (Coal): 0.0 MTCO2e
#   Generation Cost (Coal): 0.0 CAD
#   Generation (Geothermal): 8281.2 GWh
#   Emissions (Geothermal): 0.31468560000000007 MTCO2e
#   Generation Cost (Geothermal): 680714640.0000001 CAD
#   Power Plant Type Opened in 2030: Wind
#   Added Capacity for Wind in 2030: 43800 GWh
#   Cost of Capacity Increase for Wind in 2030: 4110000000.0 CAD
#   Second Power Plant Type Opened in 2030: Wind
#   Added Capacity for Wind in 2030: 43800 GWh
#   Cost of Capacity Increase for Wind in 2030: 4110000000.0 CAD
#   No Solar Power Plant Opened in 2030
#   No Second Solar Power Plant Opened in 2030
#   No Nuclear Power Plant Opened in 2030
#   No Second Nuclear Power Plant Opened in 2030
#   Total Available Capacity for Wind in 2030: 151989.48 GWh
#   Total Available Capacity for Solar in 2030: 12184.92 GWh
#   Total Available Capacity for Nuclear in 2030: 78631.37 GWh
# Total Generation Cost for Year 2030: 37201010605.8 CAD
# Total Capacity Increase Cost for Year 2030: 8220000000.0 CAD
# Total Cost for Year 2030: 45421010605.8 CAD
# Total Generation for Year 2030: 694406.6799999999 GWh
# Total Emissions for Year 2030: 39.135003539999985 MTCO2e
# Emission Deviation for Year 2030: 10.245003539999985
# Year 2035:
#   Generation (Wind): 195789.48 GWh
#   Emissions (Wind): 2.9368422 MTCO2e
#   Generation Cost (Wind): 15825663668.400002 CAD
#   Generation (Solar): 0.0 GWh
#   Emissions (Solar): 0.0 MTCO2e
#   Generation Cost (Solar): 0.0 CAD
#   Generation (Oil): 0.0 GWh
#   Emissions (Oil): 0.0 MTCO2e
#   Generation Cost (Oil): 0.0 CAD
#   Generation (Nuclear): 78631.37 GWh
#   Emissions (Nuclear): 0.94357644 MTCO2e
#   Generation Cost (Nuclear): 7002123498.5 CAD
#   Generation (Hydro): 402575.9 GWh
#   Emissions (Hydro): 9.661821600000001 MTCO2e
#   Generation Cost (Hydro): 12133637626.0 CAD
#   Generation (Natural Gas): 102563.15999999995 GWh
#   Emissions (Natural Gas): 50.25594839999997 MTCO2e
#   Generation Cost (Natural Gas): 9976318573.199995 CAD
#   Generation (Coal): 0.0 GWh
#   Emissions (Coal): 0.0 MTCO2e
#   Generation Cost (Coal): 0.0 CAD
#   Generation (Geothermal): 8281.2 GWh
#   Emissions (Geothermal): 0.31468560000000007 MTCO2e
#   Generation Cost (Geothermal): 680714640.0000001 CAD
#   Power Plant Type Opened in 2035: Wind
#   Added Capacity for Wind in 2035: 43800 GWh
#   Cost of Capacity Increase for Wind in 2035: 4110000000.0 CAD
#   No Second Wind Power Plant Opened in 2035
#   No Solar Power Plant Opened in 2035
#   No Second Solar Power Plant Opened in 2035
#   No Nuclear Power Plant Opened in 2035
#   No Second Nuclear Power Plant Opened in 2035
#   Total Available Capacity for Wind in 2035: 195789.48 GWh
#   Total Available Capacity for Solar in 2035: 12184.92 GWh
#   Total Available Capacity for Nuclear in 2035: 78631.37 GWh
# Total Generation Cost for Year 2035: 45618458006.1 CAD
# Total Capacity Increase Cost for Year 2035: 4110000000.0 CAD
# Total Cost for Year 2035: 49728458006.1 CAD
# Total Generation for Year 2035: 787841.1099999999 GWh
# Total Emissions for Year 2035: 64.11287423999998 MTCO2e
# Emission Deviation for Year 2035: 64.11287423999998

# %% [markdown]
# ## Goal Programming Model

# %%
import gurobipy as gb
from gurobipy import *

# Time periods and energy sources
Time = [2025, 2030, 2035]
Gen_tech= ["wind", "solar", "hydro", "nuclear", "natural_gas", "geothermal", "oil", "coal"]

# Generation goals for each source in each time period
Lgt= [
    [60429.05, 92547.75, 184305.21],  # Wind
    [11707.13, 15214.42, 42161.81],   # Solar
    [401733.6, 443103.1, 465887.5],   # Hydro
    [78278.04, 87724.81, 131692.29],  # Nuclear
    [87486.85, 77098.86, 41866.65],   # Natural Gas
    [8281.2, 7526.04, 19716.07],      # Geothermal
    [1355.5, 969.57, 726.09],         # Oil
    [3044.54, 0, 0]                   # Coal
]

# Demand, emission,cost goals, and emission factors
Dt= [668045.91, 770028.33, 886355.62]
It = [30568530907.76, 64177279305.40, 79264644979.28]
Mt= [35.19, 24.89, 0]

Egt = [
    [0.000015, 0.000015, 0.000015],  # Wind
    [0.0000445, 0.0000445, 0.0000445],   # Solar
    [0.000024, 0.000024, 0.000024],   # Hydro
    [0.000012, 0.000012, 0.000012],  # Nuclear
    [0.00049, 0.00049, 0.00049],   # Natural Gas
    [0.000038, 0.000038, 0.000038],      # Geothermal
    [0.00049, 0.00049, 0.00049],         # Oil
    [0.00082, 0.00082, 0.00082]                   # Coal
]

# Emission data for each source in each time period
Bgt = [
    [0.91, 1.39, 2.76],  # Wind
    [0.52, 0.68, 1.88],   # Solar
    [9.64, 10.63, 11.18],   # Hydro
    [0.94, 1.05, 1.58],  # Nuclear
    [42.67, 37.78, 20.51],   # Natural Gas
    [0.31, 0.29, 0.75],      # Geothermal
    [0.66, 0.48, 0.36],         # Oil
    [2.50, 0, 0]                   # Coal
]

# Cost data for each source in each time period
Kgt = [
    [4884480111.50, 7480634632.50, 14897390124.30],  # Wind
    [2405815215.00, 3126563310.00, 8664251955.00],   # Solar
    [24766876440.00, 27317306115.00, 28721964375.00],   # Hydro
    [6970659462.00, 7811894330.50, 11727198424.50],  # Nuclear
    [2636853659.00, 2323759640.40, 1261860831.00],   # Natural Gas
    [805512324.00, 732057910.80, 1917782128.90],      # Geothermal
    [113279135.00, 81026964.9, 60679341.3],         # Oil
    [250261188, 0, 0]                   # Coal
]

# Cost UB for each source in each time period
Kgt_UB = [
    [4884480111.50 * 1.05, 7480634632.50 * 1.05, 14897390124.30 * 1.05],  # Wind
    [2405815215.00 * 1.05, 3126563310.00 * 1.05, 8664251955.00 * 1.05],   # Solar
    [24766876440.00 * 1.05, 27317306115.00 * 1.05, 28721964375.00 * 1.05],   # Hydro
    [6970659462.00 * 1.05, 7811894330.50 * 1.05, 11727198424.50 * 1.05],  # Nuclear
    [2636853659.00 * 1.05, 2323759640.40 * 1.05, 1261860831.00 * 1.05],   # Natural Gas
    [805512324.00 * 1.05, 732057910.80 * 1.05, 1917782128.90 * 1.05],      # Geothermal
    [113279135.00 * 1.05, 81026964.9 * 1.05, 60679341.3 * 1.05],         # Oil
    [250261188 * 1.05, 0, 0]  # Coal
]

# Emission UB for each source in each time period
Bgt_UB= [
    [60429.05*0.00015*1.05, 92547.75*0.00015*1.05, 184305.21*0.00015*1.05],  # Wind
    [11707.13*0.0000445*1.05, 15214.42*0.0000445*1.05, 42161.81*0.0000445*1.05],   # Solar
    [401733.6*0.000024*1.05, 443103.1* 0.000024*1.05, 465887.5* 0.000024*1.05],   # Hydro
    [78278.04*0.000012*1.05, 87724.81*0.000012*1.05, 131692.29*0.000012*1.05],  # Nuclear
    [87486.85*0.00049*1.05, 77098.86*0.00049*1.05, 41866.65*0.00049*1.05],   # Natural Gas
    [8281.2*0.000038*1.05, 7526.04*0.000038*1.05, 19716.07*0.000038*1.05],      # Geothermal
    [1355.5*0.00049*1.05, 969.57*0.00049*1.05, 726.09*0.00049*1.05],         # Oil
    [3044.54*0.00082*1.05, 0*0.00082*1.05, 0*0.00082*1.05]                   # Coal
]

# Generation UB for each source in each time period
Lgt_UB= [
    [60429.05*1.05, 92547.75*1.05,184305.21*1.05],  # Wind
    [11707.13*1.05, 15214.42*1.05, 42161.81*1.05],   # Solar
    [401733.6*1.05, 443103.1*1.05, 465887.5*1.05],   # Hydro
    [78278.04*1.05, 87724.81*1.05, 131692.29*1.05],  # Nuclear
    [87486.85*1.05, 77098.86*1.05, 41866.65*1.05],   # Natural Gas
    [8281.2*1.05, 7526.04*1.05, 19716.07*1.05],      # Geothermal
    [1355.5*1.05, 969.57*1.05, 726.09*1.05],         # Oil
    [3044.54*1.05, 0*1.05, 0*1.05]                   # Coal
]

# Capacity UB for each source in each time period
Ugt_UB = [
    [64389.48*1.05, (64389.48 + 2 * 64389.48)*1.05, (64389.48 + 4 * 64389.48)*1.05],  # Wind
    [12184.92*1.05, (12184.92 + 2 * 12184.92)*1.05, (12184.92 + 4 * 12184.92)*1.05],  # Solar
    [401733.6*1.05, 401733.6*1.05, 401733.6*1.05],                                # Hydro
    [78631.37*1.05, 78631.37*1.05, 78631.37*1.05],                                # Nuclear
    [106529.07*1.05, 106529.07*1.05, 106529.07*1.05],                             # Natural Gas
    [8281.2*1.05, 8281.2*1.05, 8281.2*1.05],                                      # Geothermal
    [1379.91*1.05, 1379.91*1.05, 1379.91*1.05],                                   # Oil
    [8184.54*1.05, 0*1.05, 0*1.05]                                                # Coal & Coke
]

# Capacity goals 
Ugt = [
    [64389.48, 64389.48 + 2 * 64389.48, 64389.48 + 4 * 64389.48],  # Wind
    [12184.92, 12184.92 + 2 * 12184.92, 12184.92 + 4 * 12184.92],  # Solar
    [401733.6, 401733.6, 401733.6],                                # Hydro
    [78631.37, 78631.37, 78631.37],                                # Nuclear
    [106529.07, 106529.07, 106529.07],                             # Natural Gas
    [8281.2, 8281.2, 8281.2],                                      # Geothermal
    [1379.91, 1379.91, 1379.91],                                   # Oil
    [8184.54, 0, 0]                                                # Coal & Coke
]

# Singular Cost data for each source in each time period
Cgt = [
    [80830, 80830, 80830],    # Wind
    [205500, 205500, 205500], # Solar
    [61650, 61650, 61650],    # Hydro
    [89050, 89050, 89050],    # Nuclear
    [30140, 30140, 30140],    # Natural Gas
    [97270, 97270, 97270],    # Geothermal
    [83570, 83570, 83570],    # Oil
    [82200, 82200, 82200]     # Coal
]

G=range(len(Gen_tech))
T=range(len(Time))

# Create model
prob = gb.Model("CanadaEnergyModel")

# Deviation variables
ct_plus  = prob.addVars(G,T, lb=0, name='Positive Cost Deviation')
ct_minus = prob.addVars(G,T, lb=0, name='Negative Cost Deviation')
et_plus  = prob.addVars(G,T, lb=0, name='Positive Emission Deviation')
et_minus = prob.addVars(G,T, lb=0, name='Negative Emission Deviation')
gt_plus  = prob.addVars(G,T, lb=0, name='Positive Generation Deviation')
gt_minus = prob.addVars(G,T, lb=0, name='Negative Generation Deviation')
qt_plus  = prob.addVars(G,T, lb=0, name='Positive Capacity Deviation')
qt_minus = prob.addVars(G,T, lb=0, name='Negative Capacity Deviation')

for g in G:
    for t in T:
        ct_plus[g, t].setAttr('UB', Kgt_UB[g][t])
        ct_minus[g, t].setAttr('UB', Kgt_UB[g][t])
        et_plus[g, t].setAttr('UB', Bgt_UB[g][t])
        et_minus[g, t].setAttr('UB', Bgt_UB[g][t])
        gt_plus[g, t].setAttr('UB', Lgt_UB[g][t])
        gt_minus[g, t].setAttr('UB', Lgt_UB[g][t])
        qt_plus[g, t].setAttr('UB', Ugt_UB[g][t])
        qt_minus[g, t].setAttr('UB', Ugt_UB[g][t])


# Decision variables
Y = prob.addVars(G, T, lb=0, name='Generation')
X = prob.addVars(G, T, lb=0, name='Capacity')
Z = prob.addVars(G,T, lb=0, name='Emission')
C = prob.addVars(G,T, lb=0, name='Cost')


# Constraints
prob.addConstrs(Lgt[g][t] == Y[g, t] + gt_plus[g, t] - gt_minus[g, t] for g in G for t in T)
prob.addConstrs(Ugt[g][t] == X[g, t] + qt_plus[g, t] - qt_minus[g, t] for g in G for t in T)
prob.addConstrs(Bgt[g][t] == Z[g, t] + et_plus[g, t] - et_minus[g, t] for g in G for t in T)
prob.addConstrs(Kgt[g][t] == C[g, t] + ct_plus[g, t] - ct_minus[g, t] for g in G for t in T)

prob.addConstrs(Y[g, t] <= X[g, t] for g in G for t in T)
prob.addConstrs(Z[g, t] == Egt[g][t] * Y[g, t] for g in G for t in T)
prob.addConstrs(C[g, t] == Cgt[g][t] * X[g, t] for g in G for t in T)

prob.addConstrs(sum(Y[g, t] for g in G) >= Dt[t] for t in T)
prob.addConstrs(sum(C[g, t] for g in G) >= It[t] for t in T)
prob.addConstrs(sum(Z[g, t] for g in G) >= Mt[t] for t in T)

# Objectives
Emission_Deviation = sum((et_plus[g,t] + et_minus[g,t] for g in G for t in T))
Cost_Deviation = sum(ct_plus[g,t] + ct_minus[g,t] for g in G for t in T)
Generation_Deviation = sum(gt_plus[g, t] + gt_minus[g, t] for g in G for t in T)
Capacity_Deviation = sum(qt_plus[g, t] + qt_minus[g, t] for g in G for t in T)

prob.setObjectiveN(Emission_Deviation, index=0, priority=3)
prob.setObjectiveN(Generation_Deviation, index=1, priority=2)
prob.setObjectiveN(Capacity_Deviation, index=2, priority=1)
prob.setObjectiveN(Cost_Deviation, index=3, priority=0)

# Optimize
prob.optimize()

# Print solution
for v in prob.getVars():
    print(f"{v.VarName}: {v.x}")

# Print detailed results
print("\nDetailed Results:\n")
for t_idx, t in enumerate(Time):
    print(f"Time Period: {t}")
    
    for g_idx, g in enumerate(Gen_tech):
        gen = Y[g_idx, t_idx].x
        cap = X[g_idx, t_idx].x
        emission = Z[g_idx, t_idx].x
        cost = C[g_idx, t_idx].x
        gen_target = Lgt[g_idx][t_idx]
        cap_target = Ugt[g_idx][t_idx]
        emission_target = Bgt[g_idx][t_idx]
        cost_target = Kgt[g_idx][t_idx]

        # Calculate deviations
        gen_plus = max(0, gen - gen_target)
        gen_minus = max(0, gen_target - gen)
        cap_plus = max(0, cap - cap_target)
        cap_minus = max(0, cap_target - cap)
        emission_plus = max(0, emission - emission_target)  
        emission_minus = max(0, emission_target - emission)  
        cost_plus = max(0, cost - cost_target)
        cost_minus = max(0, cost_target - cost)

        print(f"  Technology: {g}")
        print(f"    Generation (GWh): {gen}")
        print(f"    Capacity (GWh): {cap}")
        print(f"    Emissions (MtCO2e): {emission}")
        print(f"    Cost (CAD): {cost}")
        print(f"    Positive Generation Deviation: {gen_plus}")
        print(f"    Negative Generation Deviation: {gen_minus}")
        print(f"    Positive Capacity Deviation: {cap_plus}")
        print(f"    Negative Capacity Deviation: {cap_minus}")
        print(f"    Positive Emissions Deviation: {emission_plus}")  
        print(f"    Negative Emissions Deviation: {emission_minus}")  
        print(f"    Positive Cost Deviation: {cost_plus}")  
        print(f"    Negative Cost Deviation: {cost_minus}")

    # Print totals for each decision variable in the current time period
    total_gen_t = sum(Y[g_idx, t_idx].x for g_idx in G)
    total_cap_t = sum(X[g_idx, t_idx].x for g_idx in G)
    total_emission_t = sum(Z[g_idx, t_idx].x for g_idx in G)
    total_cost_t = sum(C[g_idx, t_idx].x for g_idx in G)

    print("  --------------------------------------------------\n")
    print(f"  Total Generation (GWh): {total_gen_t}")
    print(f"  Total Capacity (GWh): {total_cap_t}")
    print(f"  Total Emissions (MtCO2e): {total_emission_t}")
    print(f"  Total Cost (CAD): {total_cost_t}")
    print("--------------------------------------------------\n")
    
# After optimization

# Sum decision variables over G and T dimensions 
total_gen = sum(Y[g, t].x for g in G for t in T)
total_cap = sum(X[g, t].x for g in G for t in T)  
total_emission = sum(Z[g, t].x for g in G for t in T)
total_cost = sum(C[g, t].x for g in G for t in T)

print("\nTotal across all time periods:") 
print(f"Total Generation (GWh): {total_gen}")
print(f"Total Capacity (GWh): {total_cap}")
print(f"Total Emissions (MtCO2e): {total_emission}")  
print(f"Total Cost (CAD): {total_cost}")
# Out:
# Gurobi Optimizer version 10.0.1 build v10.0.1rc0 (mac64[x86])
#
# CPU model: Intel(R) Core(TM) i5-5250U CPU @ 1.60GHz
# Thread count: 2 physical cores, 4 logical processors, using up to 4 threads
#
# Optimize a model with 177 rows, 288 columns and 504 nonzeros
# Model fingerprint: 0x49eca037
# Variable types: 288 continuous, 0 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e-05, 2e+05]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [3e-01, 3e+10]
#   RHS range        [3e-01, 8e+10]
# Warning: Model contains large rhs
# Warning: Model contains large bounds
#          Consider reformulating model or setting NumericFocus parameter
#          to avoid numerical issues.
#
# ---------------------------------------------------------------------------
# Multi-objectives: starting optimization with 4 objectives ...
# ---------------------------------------------------------------------------
#
# Multi-objectives: applying initial presolve ...
# ---------------------------------------------------------------------------
#
# Presolve removed 59 rows and 68 columns
# Presolved: 118 rows and 220 columns
# ---------------------------------------------------------------------------
#
# Multi-objectives: optimize objective 1 () ...
# ---------------------------------------------------------------------------
#
# Presolve removed 93 rows and 163 columns
# Presolve time: 0.12s
# Presolved: 25 rows, 57 columns, 85 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.0489452e-01   8.131203e+03   0.000000e+00      0s
#        3    8.8548998e-01   0.000000e+00   0.000000e+00      0s
#
# Solved in 3 iterations and 0.14 seconds (0.00 work units)
# Optimal objective  8.854899824e-01
# ---------------------------------------------------------------------------
#
# Multi-objectives: optimize objective 2 () ...
# ---------------------------------------------------------------------------
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    2.5218782e+06   0.000000e+00   1.920000e+02      0s
#       12    6.9415142e+04   0.000000e+00   0.000000e+00      0s
#
# Solved in 12 iterations and 0.17 seconds (0.00 work units)
# Optimal objective  6.941514210e+04
# ---------------------------------------------------------------------------
#
# Multi-objectives: optimize objective 3 () ...
# ---------------------------------------------------------------------------
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    2.5126114e+06   0.000000e+00   1.440035e+02      0s
#       27    2.7208999e+05   0.000000e+00   0.000000e+00      0s
#
# Solved in 27 iterations and 0.22 seconds (0.00 work units)
# Optimal objective  2.720899939e+05
# ---------------------------------------------------------------------------
#
# Multi-objectives: optimize objective 4 () ...
# ---------------------------------------------------------------------------
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.0515262e+11   0.000000e+00   4.800000e+01      0s
#        3    3.5806957e+10   0.000000e+00   0.000000e+00      0s
#
# Solved in 3 iterations and 0.26 seconds (0.00 work units)
# Optimal objective  3.580695664e+10
#
# ---------------------------------------------------------------------------
# Multi-objectives: solved in 0.27 seconds (0.00 work units), solution count 4
#
# Positive Cost Deviation[0,0]: 0.0
# Positive Cost Deviation[0,1]: 0.0
# Positive Cost Deviation[0,2]: 0.0
# Positive Cost Deviation[1,0]: 0.0
# Positive Cost Deviation[1,1]: 0.0
# Positive Cost Deviation[1,2]: 0.0
# Positive Cost Deviation[2,0]: 0.0
# Positive Cost Deviation[2,1]: 11493615.0
# Positive Cost Deviation[2,2]: 3339375.0
# Positive Cost Deviation[3,0]: 0.0
# Positive Cost Deviation[3,1]: 0.0
# Positive Cost Deviation[3,2]: 0.0
# Positive Cost Deviation[4,0]: 0.0
# Positive Cost Deviation[4,1]: 0.0
# Positive Cost Deviation[4,2]: 0.0
# Positive Cost Deviation[5,0]: 0.0
# Positive Cost Deviation[5,1]: 0.0
# Positive Cost Deviation[5,2]: 266481864.6999998
# Positive Cost Deviation[6,0]: 0.0
# Positive Cost Deviation[6,1]: 0.0
# Positive Cost Deviation[6,2]: 0.0
# Positive Cost Deviation[7,0]: 0.0
# Positive Cost Deviation[7,1]: 0.0
# Positive Cost Deviation[7,2]: 0.0
# Negative Cost Deviation[0,0]: 320121556.9000006
# Negative Cost Deviation[0,1]: 7854666364.125
# Negative Cost Deviation[0,2]: 11125618217.7
# Negative Cost Deviation[1,0]: 98185845.00000048
# Negative Cost Deviation[1,1]: 3282891475.5
# Negative Cost Deviation[1,2]: 3855753345.000002
# Negative Cost Deviation[2,0]: 0.0
# Negative Cost Deviation[2,1]: 0.0
# Negative Cost Deviation[2,2]: 0.0
# Negative Cost Deviation[3,0]: 1434942506.034646
# Negative Cost Deviation[3,1]: 4071907084.704582
# Negative Cost Deviation[3,2]: 268442019.39162254
# Negative Cost Deviation[4,0]: 573932510.8000002
# Negative Cost Deviation[4,1]: 887026529.4000001
# Negative Cost Deviation[4,2]: 1324953872.55
# Negative Cost Deviation[5,0]: 1.1920928955078125e-07
# Negative Cost Deviation[5,1]: 73454413.20000017
# Negative Cost Deviation[5,2]: 0.0
# Negative Cost Deviation[6,0]: 2039943.700000003
# Negative Cost Deviation[6,1]: 34292113.8
# Negative Cost Deviation[6,2]: 54639737.400000006
# Negative Cost Deviation[7,0]: 262774247.4
# Negative Cost Deviation[7,1]: 0.0
# Negative Cost Deviation[7,2]: 0.0
# Positive Emission Deviation[0,0]: 0.0
# Positive Emission Deviation[0,1]: 0.0
# Positive Emission Deviation[0,2]: 0.0
# Positive Emission Deviation[1,0]: 0.0
# Positive Emission Deviation[1,1]: 0.0
# Positive Emission Deviation[1,2]: 0.0
# Positive Emission Deviation[2,0]: 0.0
# Positive Emission Deviation[2,1]: 0.0
# Positive Emission Deviation[2,2]: 0.0
# Positive Emission Deviation[3,0]: 0.0
# Positive Emission Deviation[3,1]: 0.0
# Positive Emission Deviation[3,2]: 0.0
# Positive Emission Deviation[4,0]: 0.0
# Positive Emission Deviation[4,1]: 0.0
# Positive Emission Deviation[4,2]: 0.0
# Positive Emission Deviation[5,0]: 0.0
# Positive Emission Deviation[5,1]: 0.0
# Positive Emission Deviation[5,2]: 0.10489451999999988
# Positive Emission Deviation[6,0]: 0.0
# Positive Emission Deviation[6,1]: 0.0
# Positive Emission Deviation[6,2]: 0.0
# Positive Emission Deviation[7,0]: 0.0
# Positive Emission Deviation[7,1]: 0.0
# Positive Emission Deviation[7,2]: 0.0
# Negative Emission Deviation[0,0]: 0.0
# Negative Emission Deviation[0,1]: 0.0
# Negative Emission Deviation[0,2]: 0.0
# Negative Emission Deviation[1,0]: 0.0
# Negative Emission Deviation[1,1]: 0.0
# Negative Emission Deviation[1,2]: 0.0
# Negative Emission Deviation[2,0]: 0.0
# Negative Emission Deviation[2,1]: 0.0
# Negative Emission Deviation[2,2]: 0.0
# Negative Emission Deviation[3,0]: 0.1927032410602556
# Negative Emission Deviation[3,1]: 0.5514106342779896
# Negative Emission Deviation[3,2]: 0.036481587048842856
# Negative Emission Deviation[4,0]: 0.0
# Negative Emission Deviation[4,1]: 0.0
# Negative Emission Deviation[4,2]: 0.0
# Negative Emission Deviation[5,0]: 0.0
# Negative Emission Deviation[5,1]: 0.0
# Negative Emission Deviation[5,2]: 0.0
# Negative Emission Deviation[6,0]: 0.0
# Negative Emission Deviation[6,1]: 0.0
# Negative Emission Deviation[6,2]: 0.0
# Negative Emission Deviation[7,0]: 0.0
# Negative Emission Deviation[7,1]: 0.0
# Negative Emission Deviation[7,2]: 0.0
# Positive Generation Deviation[0,0]: 0.0
# Positive Generation Deviation[0,1]: 0.0
# Positive Generation Deviation[0,2]: 305.20999999999185
# Positive Generation Deviation[1,0]: 21.736741573033214
# Positive Generation Deviation[1,1]: 0.0
# Positive Generation Deviation[1,2]: 0.0
# Positive Generation Deviation[2,0]: 66.93333333329065
# Positive Generation Deviation[2,1]: 186.43333333329065
# Positive Generation Deviation[2,2]: 54.16666666668607
# Positive Generation Deviation[3,0]: 0.0
# Positive Generation Deviation[3,1]: 0.0
# Positive Generation Deviation[3,2]: 0.0
# Positive Generation Deviation[4,0]: 405.21734693877806
# Positive Generation Deviation[4,1]: 0.0
# Positive Generation Deviation[4,2]: 9.507142857139115
# Positive Generation Deviation[5,0]: 123.30526315789575
# Positive Generation Deviation[5,1]: 0.0
# Positive Generation Deviation[5,2]: 2739.609999999997
# Positive Generation Deviation[6,0]: 8.561224489795904
# Positive Generation Deviation[6,1]: 0.0
# Positive Generation Deviation[6,2]: 0.0
# Positive Generation Deviation[7,0]: 0.0
# Positive Generation Deviation[7,1]: 0.0
# Positive Generation Deviation[7,2]: 0.0
# Negative Generation Deviation[0,0]: 237.6166666666686
# Negative Generation Deviation[0,1]: 118.91666666667152
# Negative Generation Deviation[0,2]: 0.0
# Negative Generation Deviation[1,0]: 0.0
# Negative Generation Deviation[1,1]: 66.47887640449517
# Negative Generation Deviation[1,2]: 85.38101123595698
# Negative Generation Deviation[2,0]: 0.0
# Negative Generation Deviation[2,1]: 0.0
# Negative Generation Deviation[2,2]: 0.0
# Negative Generation Deviation[3,0]: 16113.896755021298
# Negative Generation Deviation[3,1]: 45726.07618983247
# Negative Generation Deviation[3,2]: 3014.508920736902
# Negative Generation Deviation[4,0]: 0.0
# Negative Generation Deviation[4,1]: 3.1808163265377516
# Negative Generation Deviation[4,2]: 0.0
# Negative Generation Deviation[5,0]: 0.0
# Negative Generation Deviation[5,1]: 105.53894736842085
# Negative Generation Deviation[5,2]: 0.0
# Negative Generation Deviation[6,0]: 0.0
# Negative Generation Deviation[6,1]: 10.021836734693807
# Negative Generation Deviation[6,2]: 8.603877551020332
# Negative Generation Deviation[7,0]: 4.240487804878285
# Negative Generation Deviation[7,1]: 0.0
# Negative Generation Deviation[7,2]: 0.0
# Positive Capacity Deviation[0,0]: 0.0
# Positive Capacity Deviation[0,1]: 3445.5524999999907
# Positive Capacity Deviation[0,2]: 0.0
# Positive Capacity Deviation[1,0]: 0.0
# Positive Capacity Deviation[1,1]: 5365.199000000004
# Positive Capacity Deviation[1,2]: 0.0
# Positive Capacity Deviation[2,0]: 0.0
# Positive Capacity Deviation[2,1]: 0.0
# Positive Capacity Deviation[2,2]: 0.0
# Positive Capacity Deviation[3,0]: 0.0
# Positive Capacity Deviation[3,1]: 0.0
# Positive Capacity Deviation[3,2]: 0.0
# Positive Capacity Deviation[4,0]: 0.0
# Positive Capacity Deviation[4,1]: 0.0
# Positive Capacity Deviation[4,2]: 20702.4375
# Positive Capacity Deviation[5,0]: 0.0
# Positive Capacity Deviation[5,1]: 0.0
# Positive Capacity Deviation[5,2]: 0.0
# Positive Capacity Deviation[6,0]: 0.0
# Positive Capacity Deviation[6,1]: 0.0
# Positive Capacity Deviation[6,2]: 0.0
# Positive Capacity Deviation[7,0]: 1943.2330000000002
# Positive Capacity Deviation[7,1]: 0.0
# Positive Capacity Deviation[7,2]: 0.0
# Negative Capacity Deviation[0,0]: 0.0
# Negative Capacity Deviation[0,1]: 0.0
# Negative Capacity Deviation[0,2]: 0.0
# Negative Capacity Deviation[1,0]: 0.0
# Negative Capacity Deviation[1,1]: 0.0
# Negative Capacity Deviation[1,2]: 0.0
# Negative Capacity Deviation[2,0]: 0.0
# Negative Capacity Deviation[2,1]: 41183.06666666671
# Negative Capacity Deviation[2,2]: 64099.73333333334
# Negative Capacity Deviation[3,0]: 15760.566755021297
# Negative Capacity Deviation[3,1]: 54819.51618983247
# Negative Capacity Deviation[3,2]: 56075.428920736915
# Negative Capacity Deviation[4,0]: 0.0
# Negative Capacity Deviation[4,1]: 0.0
# Negative Capacity Deviation[4,2]: 0.0
# Negative Capacity Deviation[5,0]: 0.0
# Negative Capacity Deviation[5,1]: 0.0
# Negative Capacity Deviation[5,2]: 8695.260000000002
# Negative Capacity Deviation[6,0]: 0.0
# Negative Capacity Deviation[6,1]: 0.0
# Negative Capacity Deviation[6,2]: 0.0
# Negative Capacity Deviation[7,0]: 0.0
# Negative Capacity Deviation[7,1]: 0.0
# Negative Capacity Deviation[7,2]: 0.0
# Generation[0,0]: 60666.666666666664
# Generation[0,1]: 92666.66666666666
# Generation[0,2]: 183999.99999999997
# Generation[1,0]: 11685.393258426968
# Generation[1,1]: 15280.898876404497
# Generation[1,2]: 42247.191011235955
# Generation[2,0]: 401666.6666666667
# Generation[2,1]: 442916.6666666667
# Generation[2,2]: 465833.3333333333
# Generation[3,0]: 94391.93675502129
# Generation[3,1]: 133450.88618983247
# Generation[3,2]: 134706.7989207369
# Generation[4,0]: 87081.63265306121
# Generation[4,1]: 77102.04081632654
# Generation[4,2]: 41857.14285714286
# Generation[5,0]: 8157.894736842105
# Generation[5,1]: 7631.57894736842
# Generation[5,2]: 16976.460000000003
# Generation[6,0]: 1346.938775510204
# Generation[6,1]: 979.5918367346939
# Generation[6,2]: 734.6938775510204
# Generation[7,0]: 3048.7804878048782
# Generation[7,1]: 0.0
# Generation[7,2]: 0.0
# Capacity[0,0]: 64389.48000000001
# Capacity[0,1]: 189722.8875
# Capacity[0,2]: 321947.4
# Capacity[1,0]: 12184.919999999998
# Capacity[1,1]: 31189.560999999998
# Capacity[1,2]: 60924.6
# Capacity[2,0]: 401733.6
# Capacity[2,1]: 442916.6666666667
# Capacity[2,2]: 465833.3333333333
# Capacity[3,0]: 94391.93675502129
# Capacity[3,1]: 133450.88618983247
# Capacity[3,2]: 134706.7989207369
# Capacity[4,0]: 106529.07
# Capacity[4,1]: 106529.07
# Capacity[4,2]: 85826.6325
# Capacity[5,0]: 8281.2
# Capacity[5,1]: 8281.2
# Capacity[5,2]: 16976.460000000003
# Capacity[6,0]: 1379.91
# Capacity[6,1]: 1379.91
# Capacity[6,2]: 1379.91
# Capacity[7,0]: 6241.307
# Capacity[7,1]: 0.0
# Capacity[7,2]: 0.0
# Emission[0,0]: 0.91
# Emission[0,1]: 1.39
# Emission[0,2]: 2.76
# Emission[1,0]: 0.52
# Emission[1,1]: 0.68
# Emission[1,2]: 1.88
# Emission[2,0]: 9.64
# Emission[2,1]: 10.63
# Emission[2,2]: 11.18
# Emission[3,0]: 1.1327032410602556
# Emission[3,1]: 1.6014106342779897
# Emission[3,2]: 1.616481587048843
# Emission[4,0]: 42.669999999999995
# Emission[4,1]: 37.78
# Emission[4,2]: 20.51
# Emission[5,0]: 0.31
# Emission[5,1]: 0.29
# Emission[5,2]: 0.6451054800000001
# Emission[6,0]: 0.66
# Emission[6,1]: 0.48
# Emission[6,2]: 0.36
# Emission[7,0]: 2.5
# Emission[7,1]: 0.0
# Emission[7,2]: 0.0
# Cost[0,0]: 5204601668.400001
# Cost[0,1]: 15335300996.625
# Cost[0,2]: 26023008342.0
# Cost[1,0]: 2504001060.0
# Cost[1,1]: 6409454785.5
# Cost[1,2]: 12520005300.0
# Cost[2,0]: 24766876440.0
# Cost[2,1]: 27305812500.0
# Cost[2,2]: 28718625000.0
# Cost[3,0]: 8405601968.034646
# Cost[3,1]: 11883801415.204582
# Cost[3,2]: 11995640443.891623
# Cost[4,0]: 3210786169.8
# Cost[4,1]: 3210786169.8
# Cost[4,2]: 2586814703.55
# Cost[5,0]: 805512324.0000001
# Cost[5,1]: 805512324.0000001
# Cost[5,2]: 1651300264.2000003
# Cost[6,0]: 115319078.7
# Cost[6,1]: 115319078.7
# Cost[6,2]: 115319078.7
# Cost[7,0]: 513035435.4
# Cost[7,1]: 0.0
# Cost[7,2]: 0.0
#
# Detailed Results:
#
# Time Period: 2025
#   Technology: wind
#     Generation (GWh): 60666.666666666664
#     Capacity (GWh): 64389.48000000001
#     Emissions (MtCO2e): 0.91
#     Cost (CAD): 5204601668.400001
#     Positive Generation Deviation: 237.61666666666133
#     Negative Generation Deviation: 0
#     Positive Capacity Deviation: 7.275957614183426e-12
#     Negative Capacity Deviation: 0
#     Positive Emissions Deviation: 0
#     Negative Emissions Deviation: 0
#     Positive Cost Deviation: 320121556.9000006
#     Negative Cost Deviation: 0
#   Technology: solar
#     Generation (GWh): 11685.393258426968
#     Capacity (GWh): 12184.919999999998
#     Emissions (MtCO2e): 0.52
#     Cost (CAD): 2504001060.0
#     Positive Generation Deviation: 0
#     Negative Generation Deviation: 21.736741573031395
#     Positive Capacity Deviation: 0
#     Negative Capacity Deviation: 1.8189894035458565e-12
#     Positive Emissions Deviation: 0
#     Negative Emissions Deviation: 0
#     Positive Cost Deviation: 98185845.0
#     Negative Cost Deviation: 0
#   Technology: hydro
#     Generation (GWh): 401666.6666666667
#     Capacity (GWh): 401733.6
#     Emissions (MtCO2e): 9.64
#     Cost (CAD): 24766876440.0
#     Positive Generation Deviation: 0
#     Negative Generation Deviation: 66.93333333329065
#     Positive Capacity Deviation: 0
#     Negative Capacity Deviation: 0
#     Positive Emissions Deviation: 0
#     Negative Emissions Deviation: 0
#     Positive Cost Deviation: 0
#     Negative Cost Deviation: 0
#   Technology: nuclear
#     Generation (GWh): 94391.93675502129
#     Capacity (GWh): 94391.93675502129
#     Emissions (MtCO2e): 1.1327032410602556
#     Cost (CAD): 8405601968.034646
#     Positive Generation Deviation: 16113.896755021298
#     Negative Generation Deviation: 0
#     Positive Capacity Deviation: 15760.566755021297
#     Negative Capacity Deviation: 0
#     Positive Emissions Deviation: 0.1927032410602556
#     Negative Emissions Deviation: 0
#     Positive Cost Deviation: 1434942506.034646
#     Negative Cost Deviation: 0
#   Technology: natural_gas
#     Generation (GWh): 87081.63265306121
#     Capacity (GWh): 106529.07
#     Emissions (MtCO2e): 42.669999999999995
#     Cost (CAD): 3210786169.8
#     Positive Generation Deviation: 0
#     Negative Generation Deviation: 405.2173469387926
#     Positive Capacity Deviation: 0
#     Negative Capacity Deviation: 0
#     Positive Emissions Deviation: 0
#     Negative Emissions Deviation: 7.105427357601002e-15
#     Positive Cost Deviation: 573932510.8000002
#     Negative Cost Deviation: 0
#   Technology: geothermal
#     Generation (GWh): 8157.894736842105
#     Capacity (GWh): 8281.2
#     Emissions (MtCO2e): 0.31
#     Cost (CAD): 805512324.0000001
#     Positive Generation Deviation: 0
#     Negative Generation Deviation: 123.30526315789575
#     Positive Capacity Deviation: 0
#     Negative Capacity Deviation: 0
#     Positive Emissions Deviation: 0
#     Negative Emissions Deviation: 0
#     Positive Cost Deviation: 1.1920928955078125e-07
#     Negative Cost Deviation: 0
#   Technology: oil
#     Generation (GWh): 1346.938775510204
#     Capacity (GWh): 1379.91
#     Emissions (MtCO2e): 0.66
#     Cost (CAD): 115319078.7
#     Positive Generation Deviation: 0
#     Negative Generation Deviation: 8.561224489795904
#     Positive Capacity Deviation: 0
#     Negative Capacity Deviation: 0
#     Positive Emissions Deviation: 0
#     Negative Emissions Deviation: 0
#     Positive Cost Deviation: 2039943.700000003
#     Negative Cost Deviation: 0
#   Technology: coal
#     Generation (GWh): 3048.7804878048782
#     Capacity (GWh): 6241.307
#     Emissions (MtCO2e): 2.5
#     Cost (CAD): 513035435.4
#     Positive Generation Deviation: 4.240487804878285
#     Negative Generation Deviation: 0
#     Positive Capacity Deviation: 0
#     Negative Capacity Deviation: 1943.2330000000002
#     Positive Emissions Deviation: 0
#     Negative Emissions Deviation: 0
#     Positive Cost Deviation: 262774247.39999998
#     Negative Cost Deviation: 0
#   --------------------------------------------------
#
#   Total Generation (GWh): 668045.91
#   Total Capacity (GWh): 695131.4237550214
#   Total Emissions (MtCO2e): 58.34270324106025
#   Total Cost (CAD): 45525734144.33465
# --------------------------------------------------
#
# Time Period: 2030
#   Technology: wind
#     Generation (GWh): 92666.66666666666
#     Capacity (GWh): 189722.8875
#     Emissions (MtCO2e): 1.39
#     Cost (CAD): 15335300996.625
#     Positive Generation Deviation: 118.91666666665697
#     Negative Generation Deviation: 0
#     Positive Capacity Deviation: 0
#     Negative Capacity Deviation: 3445.5524999999907
#     Positive Emissions Deviation: 0
#     Negative Emissions Deviation: 0
#     Positive Cost Deviation: 7854666364.125
#     Negative Cost Deviation: 0
#   Technology: solar
#     Generation (GWh): 15280.898876404497
#     Capacity (GWh): 31189.560999999998
#     Emissions (MtCO2e): 0.68
#     Cost (CAD): 6409454785.5
#     Positive Generation Deviation: 66.47887640449699
#     Negative Generation Deviation: 0
#     Positive Capacity Deviation: 0
#     Negative Capacity Deviation: 5365.199000000004
#     Positive Emissions Deviation: 0
#     Negative Emissions Deviation: 0
#     Positive Cost Deviation: 3282891475.5
#     Negative Cost Deviation: 0
#   Technology: hydro
#     Generation (GWh): 442916.6666666667
#     Capacity (GWh): 442916.6666666667
#     Emissions (MtCO2e): 10.63
#     Cost (CAD): 27305812500.0
#     Positive Generation Deviation: 0
#     Negative Generation Deviation: 186.43333333329065
#     Positive Capacity Deviation: 41183.06666666671
#     Negative Capacity Deviation: 0
#     Positive Emissions Deviation: 0
#     Negative Emissions Deviation: 0
#     Positive Cost Deviation: 0
#     Negative Cost Deviation: 11493615.0
#   Technology: nuclear
#     Generation (GWh): 133450.88618983247
#     Capacity (GWh): 133450.88618983247
#     Emissions (MtCO2e): 1.6014106342779897
#     Cost (CAD): 11883801415.204582
#     Positive Generation Deviation: 45726.07618983247
#     Negative Generation Deviation: 0
#     Positive Capacity Deviation: 54819.51618983247
#     Negative Capacity Deviation: 0
#     Positive Emissions Deviation: 0.5514106342779896
#     Negative Emissions Deviation: 0
#     Positive Cost Deviation: 4071907084.704582
#     Negative Cost Deviation: 0
#   Technology: natural_gas
#     Generation (GWh): 77102.04081632654
#     Capacity (GWh): 106529.07
#     Emissions (MtCO2e): 37.78
#     Cost (CAD): 3210786169.8
#     Positive Generation Deviation: 3.1808163265377516
#     Negative Generation Deviation: 0
#     Positive Capacity Deviation: 0
#     Negative Capacity Deviation: 0
#     Positive Emissions Deviation: 0
#     Negative Emissions Deviation: 0
#     Positive Cost Deviation: 887026529.4000001
#     Negative Cost Deviation: 0
#   Technology: geothermal
#     Generation (GWh): 7631.57894736842
#     Capacity (GWh): 8281.2
#     Emissions (MtCO2e): 0.29
#     Cost (CAD): 805512324.0000001
#     Positive Generation Deviation: 105.53894736841994
#     Negative Generation Deviation: 0
#     Positive Capacity Deviation: 0
#     Negative Capacity Deviation: 0
#     Positive Emissions Deviation: 0
#     Negative Emissions Deviation: 0
#     Positive Cost Deviation: 73454413.20000017
#     Negative Cost Deviation: 0
#   Technology: oil
#     Generation (GWh): 979.5918367346939
#     Capacity (GWh): 1379.91
#     Emissions (MtCO2e): 0.48
#     Cost (CAD): 115319078.7
#     Positive Generation Deviation: 10.021836734693807
#     Negative Generation Deviation: 0
#     Positive Capacity Deviation: 0
#     Negative Capacity Deviation: 0
#     Positive Emissions Deviation: 0
#     Negative Emissions Deviation: 0
#     Positive Cost Deviation: 34292113.8
#     Negative Cost Deviation: 0
#   Technology: coal
#     Generation (GWh): 0.0
#     Capacity (GWh): 0.0
#     Emissions (MtCO2e): 0.0
#     Cost (CAD): 0.0
#     Positive Generation Deviation: 0
#     Negative Generation Deviation: 0
#     Positive Capacity Deviation: 0
#     Negative Capacity Deviation: 0
#     Positive Emissions Deviation: 0
#     Negative Emissions Deviation: 0
#     Positive Cost Deviation: 0
#     Negative Cost Deviation: 0
#   --------------------------------------------------
#
#   Total Generation (GWh): 770028.33
#   Total Capacity (GWh): 913470.1813564991
#   Total Emissions (MtCO2e): 52.85141063427799
#   Total Cost (CAD): 65065987269.82958
# --------------------------------------------------
#
# Time Period: 2035
#   Technology: wind
#     Generation (GWh): 183999.99999999997
#     Capacity (GWh): 321947.4
#     Emissions (MtCO2e): 2.76
#     Cost (CAD): 26023008342.0
#     Positive Generation Deviation: 0
#     Negative Generation Deviation: 305.21000000002095
#     Positive Capacity Deviation: 0
#     Negative Capacity Deviation: 0
#     Positive Emissions Deviation: 0
#     Negative Emissions Deviation: 0
#     Positive Cost Deviation: 11125618217.7
#     Negative Cost Deviation: 0
#   Technology: solar
#     Generation (GWh): 42247.191011235955
#     Capacity (GWh): 60924.6
#     Emissions (MtCO2e): 1.88
#     Cost (CAD): 12520005300.0
#     Positive Generation Deviation: 85.38101123595698
#     Negative Generation Deviation: 0
#     Positive Capacity Deviation: 0
#     Negative Capacity Deviation: 0
#     Positive Emissions Deviation: 0
#     Negative Emissions Deviation: 0
#     Positive Cost Deviation: 3855753345.0
#     Negative Cost Deviation: 0
#   Technology: hydro
#     Generation (GWh): 465833.3333333333
#     Capacity (GWh): 465833.3333333333
#     Emissions (MtCO2e): 11.18
#     Cost (CAD): 28718625000.0
#     Positive Generation Deviation: 0
#     Negative Generation Deviation: 54.16666666668607
#     Positive Capacity Deviation: 64099.73333333334
#     Negative Capacity Deviation: 0
#     Positive Emissions Deviation: 0
#     Negative Emissions Deviation: 0
#     Positive Cost Deviation: 0
#     Negative Cost Deviation: 3339375.0
#   Technology: nuclear
#     Generation (GWh): 134706.7989207369
#     Capacity (GWh): 134706.7989207369
#     Emissions (MtCO2e): 1.616481587048843
#     Cost (CAD): 11995640443.891623
#     Positive Generation Deviation: 3014.508920736902
#     Negative Generation Deviation: 0
#     Positive Capacity Deviation: 56075.428920736915
#     Negative Capacity Deviation: 0
#     Positive Emissions Deviation: 0.036481587048842856
#     Negative Emissions Deviation: 0
#     Positive Cost Deviation: 268442019.39162254
#     Negative Cost Deviation: 0
#   Technology: natural_gas
#     Generation (GWh): 41857.14285714286
#     Capacity (GWh): 85826.6325
#     Emissions (MtCO2e): 20.51
#     Cost (CAD): 2586814703.55
#     Positive Generation Deviation: 0
#     Negative Generation Deviation: 9.507142857139115
#     Positive Capacity Deviation: 0
#     Negative Capacity Deviation: 20702.4375
#     Positive Emissions Deviation: 0
#     Negative Emissions Deviation: 0
#     Positive Cost Deviation: 1324953872.5500002
#     Negative Cost Deviation: 0
#   Technology: geothermal
#     Generation (GWh): 16976.460000000003
#     Capacity (GWh): 16976.460000000003
#     Emissions (MtCO2e): 0.6451054800000001
#     Cost (CAD): 1651300264.2000003
#     Positive Generation Deviation: 0
#     Negative Generation Deviation: 2739.609999999997
#     Positive Capacity Deviation: 8695.260000000002
#     Negative Capacity Deviation: 0
#     Positive Emissions Deviation: 0
#     Negative Emissions Deviation: 0.10489451999999988
#     Positive Cost Deviation: 0
#     Negative Cost Deviation: 266481864.6999998
#   Technology: oil
#     Generation (GWh): 734.6938775510204
#     Capacity (GWh): 1379.91
#     Emissions (MtCO2e): 0.36
#     Cost (CAD): 115319078.7
#     Positive Generation Deviation: 8.603877551020332
#     Negative Generation Deviation: 0
#     Positive Capacity Deviation: 0
#     Negative Capacity Deviation: 0
#     Positive Emissions Deviation: 0
#     Negative Emissions Deviation: 0
#     Positive Cost Deviation: 54639737.400000006
#     Negative Cost Deviation: 0
#   Technology: coal
#     Generation (GWh): 0.0
#     Capacity (GWh): 0.0
#     Emissions (MtCO2e): 0.0
#     Cost (CAD): 0.0
#     Positive Generation Deviation: 0
#     Negative Generation Deviation: 0
#     Positive Capacity Deviation: 0
#     Negative Capacity Deviation: 0
#     Positive Emissions Deviation: 0
#     Negative Emissions Deviation: 0
#     Positive Cost Deviation: 0
#     Negative Cost Deviation: 0
#   --------------------------------------------------
#
#   Total Generation (GWh): 886355.62
#   Total Capacity (GWh): 1087595.13475407
#   Total Emissions (MtCO2e): 38.95158706704884
#   Total Cost (CAD): 83610713132.34161
# --------------------------------------------------
#
#
# Total across all time periods:
# Total Generation (GWh): 2324429.86
# Total Capacity (GWh): 2696196.7398655913
# Total Emissions (MtCO2e): 150.1457009423871
# Total Cost (CAD): 194202434546.50586
